# %% [markdown]
# # Part 1: RNF Function Testing and Evaluation
# ## Step 1: Preprocessing US Social Security Data for RNF (Relative Name Frequency) Function
# #### Notes
# * Same as in main model
# * Like main model, the unique name-gender-frequency US Social Security data will be used as the RNF function's frame of reference, or its 'df_train' parameter

# %%
# Import Dependencies
import pandas as pd
import os
import psycopg2
from sqlalchemy import create_engine
from getpass import getpass
import random
from nltk.corpus import names
import nltk

# %%
# Folder Path
path = (r"C:\Users\benmo\OneDrive\Desktop\Capstone Project\Final-Project-Sunshine-Segment3\Resources\Resources_ML\names")
  
# Change the directory
os.chdir(path)

names_list = []

for file in os.listdir():
    file_path = rf"{path}\{file}"
    year = file[3:7]
    df_temp = pd.read_csv(file_path, names=["first_name", "gender", "frequency"])
    df_temp["year"] = year
    names_list.append(df_temp)

# %%
# Import dependency to help combine all 'names_list' items--each US Social Security Names File DF--into one large DF
from functools import reduce

# Use dependency + lambda function to execute individual DF consolidation 
total_us_ss_df = reduce(lambda x, y: x.append(y), names_list).reset_index(drop=True)

# Display output (which is one large dataframe that has combined all of the DFs in 'names_list')
total_us_ss_df
# Out:
#         first_name gender  frequency  year
# 0             Mary      F       7065  1880
# 1             Anna      F       2604  1880
# 2             Emma      F       2003  1880
# 3        Elizabeth      F       1939  1880
# 4           Minnie      F       1746  1880
# ...            ...    ...        ...   ...
# 2020858     Zykell      M          5  2020
# 2020859      Zylus      M          5  2020
# 2020860     Zymari      M          5  2020
# 2020861        Zyn      M          5  2020
# 2020862      Zyran      M          5  2020
#
# [2020863 rows x 4 columns]

# %%
# Grouping the above DF by first name and gender and summing the frequency 
# Purpose of grouping by first name is to have a DF consisting of only the unique names across all of the DFs (across all of the US Social Security Data's annual name files)
# Purpose of grouping by gender is to ensure that any multi-gender first name does not have its M/F frequencies combined into one frequency, but rather have one instance for each
# Purpose of summing frequency is to tally each unique name-gender combination across all of the years (1880-2020)
# *NOTE: The original US Social Security name files contain a name, associated gender and the frequency or how many people had that name and gender in that given year. Moreover, every year the frequency for each name is adjusted for births and deaths of people with that name. Further, each year, names are added and eliminated from the list based on succeeding / failing to meet the required minimum name-gender frequency of 5. Therefore, there is certainly overlap in the frequency if you consider individual people, but that is not relevant for our purposes. 
sum_frequencies_df = total_us_ss_df.groupby(["first_name", "gender"])[["frequency"]].sum().reset_index()

# Displaying output
sum_frequencies_df
# Out:
#        first_name gender  frequency
# 0           Aaban      M        120
# 1           Aabha      F         46
# 2           Aabid      M         16
# 3         Aabidah      F          5
# 4           Aabir      M         10
# ...           ...    ...        ...
# 111467     Zyvion      M          5
# 111468      Zyvon      M          7
# 111469    Zyyanna      F          6
# 111470      Zyyon      M          6
# 111471      Zzyzx      M         10
#
# [111472 rows x 3 columns]

# %%
# Using inverted loc on above DF's 'first_name' column to find all of the names that do not have a duplicate 
# Purpose of this is to find all of the names that are not multi-gender and separate them from the names that are historically multi-gender--so if at any point in the US from 1880-2020 there were 5 or more instances of a first name with a Male associated gender and five or more instances of the same name with a Female associated gender they will not be included in this extraction--
not_duplicated = sum_frequencies_df.loc[~sum_frequencies_df.duplicated(subset=["first_name"], keep=False)]

# Pivoting the above DF so that the binary values within the 'gender' column become two distinct columns of their own--rather than one gender column-- and their associated values will be the frequency of each gender for each name since the 'first_name' column is set to the index
# Even though the names in the DF created above are not duplicated--meaning they will only have a value for one of the 'M' or 'F' columns this is done for later purposes when this DF will be combined with another one
not_duplicated_pivoted = not_duplicated.pivot_table(values="frequency", index="first_name", columns="gender").fillna(0)

# Removing original gender column
not_duplicated_pivoted.columns.name=None

# Resetting index
not_duplicated_final = not_duplicated_pivoted.reset_index()

# Displaying output
not_duplicated_final
# Out:
#       first_name     F      M
# 0          Aaban   0.0  120.0
# 1          Aabha  46.0    0.0
# 2          Aabid   0.0   16.0
# 3        Aabidah   5.0    0.0
# 4          Aabir   0.0   10.0
# ...          ...   ...    ...
# 89251     Zyvion   0.0    5.0
# 89252      Zyvon   0.0    7.0
# 89253    Zyyanna   6.0    0.0
# 89254      Zyyon   0.0    6.0
# 89255      Zzyzx   0.0   10.0
#
# [89256 rows x 3 columns]

# %%
# Same thing as above except with the opposite data--all multi-gender first names
duplicated = sum_frequencies_df.loc[sum_frequencies_df.duplicated(subset=["first_name"], keep=False)]
duplicated_pivoted = duplicated.pivot_table(values="frequency", index="first_name", columns="gender")
duplicated_pivoted.columns.name=None
duplicated_final = duplicated_pivoted.reset_index()
duplicated_final
# Out:
#       first_name      F     M
# 0          Aaden      5  4975
# 1           Aadi     16   933
# 2          Aadyn     16   555
# 3        Aalijah    149   244
# 4        Aaliyah  94707   101
# ...          ...    ...   ...
# 11103      Zymir      5  1048
# 11104       Zyon    661  3026
# 11105      Zyonn      5    59
# 11106      Zyree     16   116
# 11107      Zyrie     26    33
#
# [11108 rows x 3 columns]

# %%
# Combining the two DFs created in the two cells above and sorting them by alphabetically by first name
final_best_df = not_duplicated_final.append(duplicated_final).sort_values(by="first_name").fillna(0)

# Changing the 'F' and 'M' frequency columns in the above DF to be an integer datatype rather than a float to get rid of the decimal for each value
final_best_df = final_best_df.astype({"F": int, "M": int})

# Displaying output
final_best_df
# Out:
#       first_name   F    M
# 0          Aaban   0  120
# 1          Aabha  46    0
# 2          Aabid   0   16
# 3        Aabidah   5    0
# 4          Aabir   0   10
# ...          ...  ..  ...
# 89251     Zyvion   0    5
# 89252      Zyvon   0    7
# 89253    Zyyanna   6    0
# 89254      Zyyon   0    6
# 89255      Zzyzx   0   10
#
# [100364 rows x 3 columns]

# %% [markdown]
# ## Step 2: Create RNF Function
# #### Notes:
# * Same as in main model

# %%
# Defining 'generate_preds' function and 'df_train' and 'df_test' as parameters to function
# *NOTE: 'df_test' is the input DF given by function user--the function will then use preprocessed data to output a gender prediction for each name wihtin 'test_df'--
# *NOTE: 'df_train' represents the data preprocessed in step 1 that will be used in below algorithm to calculate probability of input_df name being either male/female
def generate_preds(df_train, df_test):
    
    # Strips all values of input DF 'first_name' column to eliminate any formating errors that could cause function to output an error
    df_test.first_name = df_test.first_name.str.strip()
    # Sorts test values alphabetically by first name (not really needed I guess)
    df_test = df_test.sort_values(by='first_name')
    
    # Calculate probability of each name in preprocessed data being male by using unique name instances with respective male/female gender frequency from preprocessed data and insert a new column in final preprocessed DF (final_best_df) to store values
    df_train['pom'] = ((df_train.M)/(df_train.M + df_train.F))*100
     # Calculate probability of each name in preprocessed data being female by using unique name instances with respective male/female gender frequency from preprocessed data and insert a new column in final preprocessed DF (final_best_df) to store values
    df_train['pof'] = ((df_train.F)/(df_train.M + df_train.F))*100
    
    # Executing left join on 'df_test' with 'df_train' on 'df_train' 'first_name' column so that all of the (first name) data from 'df_test' is kept and only the gender probabilities (new columns being merged to 'df_test') that occur in both DFs are added to 'df_test' rather than also adding all of the names from 'df_train' that are not in 'df_test' and their respective probabilities because the function user only wants the function to output a prediction for the names they gave the function ('df_test') 
    df_merged = df_test.merge(df_train, on='first_name', how='left')
    
    # Instantiating empty list to store values output by below loop
    preds = []
    # Iterating through each row in the merged DF 
    # *NOTE: 'itertuples()' method is used for DF looping efficiency and since it provides ability to access each DF column using dot notation
    for t in df_merged.itertuples():
        # States that if merged DF 'pom'--probability of male-- column is above 50% and 'pof'--probability of female-- column is below 50% to add an 'M' to the 'preds' list because the model has dictated that the gender prediction for the respective name is male 
        if (t.pom > 50 and t.pof < 50):
            preds.append('M')
        # States that if merged DF 'pof'--probability of female-- column is above 50% and 'pom'--probability of male-- column is below 50% to add an 'F' to the 'preds' list because the model has dictated that the gender prediction for the respective name is female
        elif (t.pof > 50 and t.pom < 50):
            preds.append('F')
        # States that if the probability of a name being male/female is 50%-50% to output 'EV'--standing for even-- to the 'preds' list since the respective gender neutral name's gender cannot be predicted using this model due to insufficient data 
        elif (t.pom == 50 and t.pof == 50):
            preds.append('EV')
        # States that if none of the above can be executed to output 'U'--standing for unknown-- to the 'preds' list since the name cannot be predicted by the model due to there being no data on this name (name is not included in 'df_train')
        else:
            preds.append('U')
    # Creating a new column in the 'df_test' DF and assigning it to the 'preds' list which contains all of the gender predictions output by the model
    df_test['gender'] = preds 
    
    # Returns the same DF that the function-user input with another column that contains a gender prediction for each name from the input DF
    return df_test

# %% [markdown]
# # Step 3: Create Labeled DF from NLTK Default Name-Gender Supervised Data for RNF Testing/Evaluation
# #### Notes
# * Created from 'male.txt' and 'female.txt' files that come with NLTK library
# * Original data was two separate name lists: one for male and one for female
# * The two distinct lists are each given a gender column ("Actual") and then combined into one DataFrame
# * Resulting DF will be used to evaluate the RNF function's gender predictions (that will be made later) by using this actual gender data to determine accuracy

# %%
def gender_features(word):
    return {'last_letter':word}
  
# Preparing a list of examples and corresponding class labels.
labeled_names = ([(name, 'M') for name in names.words('male.txt')]+
             [(name, 'F') for name in names.words('female.txt')])

# %%
random.shuffle(labeled_names)

# %%
test_data_eval = pd.DataFrame(labeled_names, columns=["first_name", "Actual"])
test_data_eval = test_data_eval.sort_values(by='first_name').reset_index(drop=True)
test_data_eval
# Out:
#      first_name Actual
# 0         Aamir      M
# 1         Aaron      M
# 2       Abagael      F
# 3       Abagail      F
# 4          Abbe      F
# ...         ...    ...
# 7939      Zorro      M
# 7940    Zsa Zsa      F
# 7941     Zsazsa      F
# 7942     Zulema      F
# 7943     Zuzana      F
#
# [7944 rows x 2 columns]

# %% [markdown]
# # Step 4: Extract 'first_name' Column
# #### Notes
# * Extracting 'first_name' column from DF above and assigning it to a variable
# * Variable will be used further along in this analysis

# %%
rnf_test = test_data_eval[["first_name"]]
rnf_test
# Out:
#      first_name
# 0         Aamir
# 1         Aaron
# 2       Abagael
# 3       Abagail
# 4          Abbe
# ...         ...
# 7939      Zorro
# 7940    Zsa Zsa
# 7941     Zsazsa
# 7942     Zulema
# 7943     Zuzana
#
# [7944 rows x 1 columns]

# %% [markdown]
# # Step 5: Run RNF Function
# #### Notes
# * Running RNF function with first name data extracted above as 'test_df' input parameter
# * RNF function is using 'final_best_df' as 'train_df' input --> meaning the RNF function is using the gender probabilities it calculated from the US Social Security name-gender-frequency data to predict the gender of each name passed from the 'df_test' input parameter, which is the 'rnf_test' variable defined above

# %%
rnf_preds_df = generate_preds(final_best_df, rnf_test).reset_index(drop=True)
rnf_preds_df
# Out:
# C:\Users\benmo\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#      first_name gender
# 0         Aamir      M
# 1         Aaron      M
# 2       Abagael      F
# 3       Abagail      F
# 4          Abbe      F
# ...         ...    ...
# 7939      Zorro      U
# 7940    Zsa Zsa      U
# 7941     Zsazsa      F
# 7942     Zulema      F
# 7943     Zuzana      F
#
# [7944 rows x 2 columns]

# %% [markdown]
# # Step 6: Join 'Actual' Column to RNF Function Output
# #### Notes
# * The 'Actual' column (containing the actual genders of the labeled data) is extracted from the 'test_data_eval' DF to display a side-by-side comparison of the RNF gender predictions vs. their actual genders
# * Purpose is for performing accuracy evaluation calculation on the RNF function's predictions ('gender' column below)

# %%
actual = test_data_eval["Actual"]
rnf_final = rnf_preds_df.join(actual)
rnf_final
# Out:
#      first_name gender Actual
# 0         Aamir      M      M
# 1         Aaron      M      M
# 2       Abagael      F      F
# 3       Abagail      F      F
# 4          Abbe      F      F
# ...         ...    ...    ...
# 7939      Zorro      U      M
# 7940    Zsa Zsa      U      F
# 7941     Zsazsa      F      F
# 7942     Zulema      F      F
# 7943     Zuzana      F      F
#
# [7944 rows x 3 columns]

# %% [markdown]
# #### Notes (cont.)
# * As seen below the RNF function can only output a gender prediction for those first names that are contained in the 'train_df' parameter passed to the function
# * Names contained in the 'test_df' parameter that are not in the 'train_df' will receive a "U" prediction standing for 'unknown' because the RNF function has no way of calculating these names' gender probabilities and therefore cannot output a gender prediction, opposed to names that the function has name-gender-frequency data on (passed to the function via the 'train_df' parameter) to calculate probability

# %%
rnf_final.value_counts("gender")
# Out:
# gender
# F     4269
# M     2627
# U     1046
# EV       2
# dtype: int64

# %% [markdown]
# # Step 7: Accuracy Evaluation
# #### Notes
# * An empty list is declared to hold results
# * A for loop is used to iterate through the above DF ('rnf_final')
# * Six conditionals are delcared that will compare the 'gender' column (RNF gender predictions) to the 'Actual' column (actual genders)
# * Each conditional represents a possible outcome of the two columns from 'rnf_final' being compared and each one contains the appropriate subsequent action to accurately document whether the RNF gender prediction was correct or incorrect
# * Each "C" (correct) and "I" (incorrect) is appended to the empty list declared prior
# * Finally this list is appended as a column to the 'rnf_final' DF for convenient further analysis

# %%
accuracy_list = []
for row in rnf_final.itertuples():
    if row.gender == "M" and row.Actual == "M":
        accuracy_list.append("C")
    elif row.gender == "M" and row.Actual == "F":
        accuracy_list.append("I")
    elif row.gender == "F" and row.Actual == "F":
        accuracy_list.append("C")
    elif row.gender == "F" and row.Actual == "M":
        accuracy_list.append("I")
    elif row.gender == "U":
        accuracy_list.append("I")
    elif row.gender == "EV":
        accuracy_list.append("I")
rnf_final["Evaluation"] = accuracy_list

# %%
rnf_final.replace(to_replace={})
# Out:
#      first_name gender Actual Evaluation
# 0         Aamir      M      M          C
# 1         Aaron      M      M          C
# 2       Abagael      F      F          C
# 3       Abagail      F      F          C
# 4          Abbe      F      F          C
# ...         ...    ...    ...        ...
# 7939      Zorro      U      M          I
# 7940    Zsa Zsa      U      F          I
# 7941     Zsazsa      F      F          C
# 7942     Zulema      F      F          C
# 7943     Zuzana      F      F          C
#
# [7944 rows x 4 columns]

# %%
rnf_final
# Out:
#      first_name gender Actual Evaluation
# 0         Aamir      M      M          C
# 1         Aaron      M      M          C
# 2       Abagael      F      F          C
# 3       Abagail      F      F          C
# 4          Abbe      F      F          C
# ...         ...    ...    ...        ...
# 7939      Zorro      U      M          I
# 7940    Zsa Zsa      U      F          I
# 7941     Zsazsa      F      F          C
# 7942     Zulema      F      F          C
# 7943     Zuzana      F      F          C
#
# [7944 rows x 4 columns]

# %% [markdown]
# # Step 8: RNF Function Accuracy Score Evaluation

# %%
rnf_final.value_counts("Evaluation")
# Out:
# Evaluation
# C    6292
# I    1652
# dtype: int64

# %%
accuracy_score = (6292/(6292+1652))*100

# %%
print(f"When using the US Social Security Data as its base, the relative name frequency model accurately predicted {accuracy_score:.2f}% of the default NLTK name-gender dataset.")
# Out:
# When using the US Social Security Data as its base, the relative name frequency model accurately predicted 79.20% of the default NLTK name-gender dataset.

# %% [markdown]
# # Part 2: NLTK Library Naive Bayes Classification Model Testing/Evaluation
# ## Step 1: Preprocess US Social Security Name-Gender Data for Naive Bayes
# #### Notes
# * This is the same process used in the main ML model file to preprocess the US Social Security name-gender data so it can be used as training for the Naive Bayes Classification Model
# * US Social Security name-gender data must be preprocessed appropriately to be used to train an NLTK Naive Bayes Classification Model as per the library's documentation states
# * For this specific library-model instance the training data must be in a format comprising a list of tuples where each tuple contains a python dictionary where the key is, 'last three letters' and the value is the last three letters of each name being fed to the model for training
#  - **Note**: Doesn't have to be last three letters, this can be modified by user as desired (our choice of last three letters is explained in README)
# * Outside the dictionary, but still within the tuple, there is one more value which is the target/output variable, which in our case is the gender prediction that is represented as either "M" or "F"

# %%
# Import dependencies 
import random
from nltk.corpus import names
import nltk
import sklearn
import pandas as pd
import numpy as np

# %% [markdown]
# # Note
# * The below DF is the raw data being used to train the NLTK Naive Bayes Classification Model
# * Originally, the data used for the output ("gender") column was from 'final_best_df' which is a list of unique names from the US Social Security data
# * Further, the original output ("gender") was the result of running the RNF function on each unique name and their relative male/female frequencies to calculate gender probability and output a prediction
# * However, upon further consideration we realized that although minute, this was not optimal due to the following:
# * The Naive Bayes Classification Model outputs a gender prediction by analyzing the n-gram frequency from its training data (e.g. if the model is passed "Ben" it would look to see how freuqent the n-grams 'B', 'BE', 'EN', and 'BEN' are among male names and among female names and apply certain weights to each to output a gender prediction) Therefore, if the model is trained without seeing the multigender name instances from a female and male perspective but rather, only the lone gender prediction output by the RNF function, it can be argued that it would be missing data that could increase the model's accuracy
# * This would only effect the multi-gender name instances which is 11,108 names out of over 110k+ (< 10%)
# * Further, it stands that this ultimately should not signifcantly effect the model's accuracy because the RNF model always output the gender prediction that was most probable for each given name based on the male/female frequency data for each name
# * In summary, the n-grams that made up the multi-gender name instances were previously only associated with the prediction that was output by the RNF model (since that was used as the tagret variable) but it was decided to use the data that included a separate row for each name-gender combination (Avery, M & Avery F as two distinct rows) so that the n-grams from these multi-gender names could be associated with both genders so if for example, before there was a row that had the following data:
#  - First Name: Avery
#  - M-Freq: 100
#  - F-Freq: 3000
#  - RNF Gender Prediction: Female
# * Therefore the n-grams 'A', 'V', 'E', 'R', 'Y', 'AV', 'VE', 'ER', 'RY', 'AVE', 'VER', and 'ERY' would all get a tally in the female category within the NLTK algorithm, but the new method would give a tally to both the male and female categories since there is now an Avery instance for each, so it is possible that these could add up to change the NLTK algorithm for any given name and ultimately, its output/prediction
# **Update: After comparing the results of both methods the newer method provided the NLTK algorithm with one additional correct gender prediction*

# %%
nltk_training_data = sum_frequencies_df[["first_name", "gender"]]
nltk_training_data
# Out:
#        first_name gender
# 0           Aaban      M
# 1           Aabha      F
# 2           Aabid      M
# 3         Aabidah      F
# 4           Aabir      M
# ...           ...    ...
# 111467     Zyvion      M
# 111468      Zyvon      M
# 111469    Zyyanna      F
# 111470      Zyyon      M
# 111471      Zzyzx      M
#
# [111472 rows x 2 columns]

# %%
# Creating a new variable for the above DF and converting values to list
labeled_names = nltk_training_data.to_numpy().tolist()

# Creating a function that takes a string input and and returns a dictionary with a key of 'last three letters' and a value of the the last three letters of the input string
# *NOTE: This function and the list comp below were taken from the NLTK library's documentation explaining how to use the library
def gender_features(word):
    return {'last three letters' :word[-3:]}

# Using list comprehension and the function created above as the expression output to return a new list that includes the last three letters of each name and the gender from each item in 'labeled_names'
featuresets = [(gender_features(n), gender)
               for (n, gender)in labeled_names]

# Displaying output
featuresets
# Out:
# [({'last three letters': 'ban'}, 'M'),
#  ({'last three letters': 'bha'}, 'F'),
#  ({'last three letters': 'bid'}, 'M'),
#  ({'last three letters': 'dah'}, 'F'),
#  ({'last three letters': 'bir'}, 'M'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'ada'}, 'F'),
#  ({'last three letters': 'dam'}, 'M'),
#  ({'last three letters': 'dan'}, 'M'),
#  ({'last three letters': 'rsh'}, 'M'),
#  ({'last three letters': 'dav'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'den'}, 'F'),
#  ({'last three letters': 'den'}, 'M'),
#  ({'last three letters': 'esh'}, 'M'),
#  ({'last three letters': 'han'}, 'M'),
#  ({'last three letters': 'hav'}, 'M'),
#  ({'last three letters': 'van'}, 'M'),
#  ({'last three letters': 'dhi'}, 'M'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'ran'}, 'M'),
#  ({'last three letters': 'vik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'hya'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ddy'}, 'F'),
#  ({'last three letters': 'sri'}, 'F'),
#  ({'last three letters': 'adi'}, 'F'),
#  ({'last three letters': 'adi'}, 'M'),
#  ({'last three letters': 'ian'}, 'M'),
#  ({'last three letters': 'dil'}, 'M'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'din'}, 'M'),
#  ({'last three letters': 'ish'}, 'M'),
#  ({'last three letters': 'son'}, 'F'),
#  ({'last three letters': 'dit'}, 'M'),
#  ({'last three letters': 'ith'}, 'M'),
#  ({'last three letters': 'hya'}, 'M'),
#  ({'last three letters': 'tri'}, 'F'),
#  ({'last three letters': 'tya'}, 'M'),
#  ({'last three letters': 'div'}, 'M'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'don'}, 'M'),
#  ({'last three letters': 'ian'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'rit'}, 'M'),
#  ({'last three letters': 'iti'}, 'F'),
#  ({'last three letters': 'dvi'}, 'F'),
#  ({'last three letters': 'vik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'dya'}, 'F'),
#  ({'last three letters': 'ant'}, 'M'),
#  ({'last three letters': 'dyn'}, 'F'),
#  ({'last three letters': 'dyn'}, 'M'),
#  ({'last three letters': 'fia'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'een'}, 'F'),
#  ({'last three letters': 'gam'}, 'M'),
#  ({'last three letters': 'age'}, 'M'),
#  ({'last three letters': 'gna'}, 'F'),
#  ({'last three letters': 'got'}, 'F'),
#  ({'last three letters': 'aan'}, 'M'),
#  ({'last three letters': 'han'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'eli'}, 'F'),
#  ({'last three letters': 'hid'}, 'M'),
#  ({'last three letters': 'hil'}, 'M'),
#  ({'last three letters': 'hir'}, 'M'),
#  ({'last three letters': 'ani'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'hna'}, 'F'),
#  ({'last three letters': 'ron'}, 'M'),
#  ({'last three letters': 'dan'}, 'M'),
#  ({'last three letters': 'den'}, 'M'),
#  ({'last three letters': 'dyn'}, 'M'),
#  ({'last three letters': 'ila'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ima'}, 'F'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'rah'}, 'F'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'hah'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'iza'}, 'F'),
#  ({'last three letters': 'aja'}, 'F'),
#  ({'last three letters': 'jah'}, 'F'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'jon'}, 'M'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'rsh'}, 'M'),
#  ({'last three letters': 'ash'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'kif'}, 'M'),
#  ({'last three letters': 'kil'}, 'M'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'iti'}, 'F'),
#  ({'last three letters': 'ala'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'lam'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nah'}, 'F'),
#  ({'last three letters': 'ani'}, 'F'),
#  ({'last three letters': 'lap'}, 'M'),
#  ({'last three letters': 'sia'}, 'F'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'jah'}, 'F'),
#  ({'last three letters': 'yna'}, 'F'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'sia'}, 'F'),
#  ({'last three letters': 'lea'}, 'F'),
#  ({'last three letters': 'eah'}, 'F'),
#  ({'last three letters': 'hya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ena'}, 'F'),
#  ({'last three letters': 'eya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'eia'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'gha'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ena'}, 'F'),
#  ({'last three letters': 'xis'}, 'F'),
#  ({'last three letters': 'xus'}, 'F'),
#  ({'last three letters': 'eya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ali'}, 'M'),
#  ({'last three letters': 'lia'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'ias'}, 'M'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ayh'}, 'F'),
#  ({'last three letters': 'cia'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'iha'}, 'F'),
#  ({'last three letters': 'jah'}, 'F'),
#  ({'last three letters': 'jah'}, 'M'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'lim'}, 'M'),
#  ({'last three letters': 'mah'}, 'F'),
#  ({'last three letters': 'lin'}, 'F'),
#  ({'last three letters': 'ina'}, 'F'),
#  ({'last three letters': 'nah'}, 'F'),
#  ({'last three letters': 'isa'}, 'F'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'via'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yaa'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yah'}, 'M'),
#  ({'last three letters': 'aha'}, 'F'),
#  ({'last three letters': 'rie'}, 'F'),
#  ({'last three letters': 'ose'}, 'F'),
#  ({'last three letters': 'yan'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'yha'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'lok'}, 'M'),
#  ({'last three letters': 'lon'}, 'M'),
#  ({'last three letters': 'oni'}, 'F'),
#  ({'last three letters': 'lya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'cia'}, 'F'),
#  ({'last three letters': 'yha'}, 'F'),
#  ({'last three letters': 'yia'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'yna'}, 'F'),
#  ({'last three letters': 'sia'}, 'F'),
#  ({'last three letters': 'ssa'}, 'F'),
#  ({'last three letters': 'via'}, 'F'),
#  ({'last three letters': 'nda'}, 'F'),
#  ({'last three letters': 'nee'}, 'F'),
#  ({'last three letters': 'ani'}, 'F'),
#  ({'last three letters': 'mar'}, 'M'),
#  ({'last three letters': 'ara'}, 'F'),
#  ({'last three letters': 'ari'}, 'F'),
#  ({'last three letters': 'ari'}, 'M'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'ber'}, 'F'),
#  ({'last three letters': 'ena'}, 'F'),
#  ({'last three letters': 'mer'}, 'M'),
#  ({'last three letters': 'mia'}, 'F'),
#  ({'last three letters': 'mil'}, 'M'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'ina'}, 'F'),
#  ({'last three letters': 'nah'}, 'F'),
#  ({'last three letters': 'mir'}, 'F'),
#  ({'last three letters': 'mir'}, 'M'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'rah'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'mna'}, 'F'),
#  ({'last three letters': 'oni'}, 'F'),
#  ({'last three letters': 'ora'}, 'F'),
#  ({'last three letters': 'rah'}, 'F'),
#  ({'last three letters': 'ori'}, 'F'),
#  ({'last three letters': 'mya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'and'}, 'M'),
#  ({'last three letters': 'nav'}, 'M'),
#  ({'last three letters': 'nay'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'hal'}, 'F'),
#  ({'last three letters': 'nia'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'jah'}, 'F'),
#  ({'last three letters': 'nik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'sah'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'nsh'}, 'M'),
#  ({'last three letters': 'shi'}, 'F'),
#  ({'last three letters': 'nvi'}, 'F'),
#  ({'last three letters': 'nya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yla'}, 'F'),
#  ({'last three letters': 'pri'}, 'F'),
#  ({'last three letters': 'qib'}, 'M'),
#  ({'last three letters': 'qil'}, 'M'),
#  ({'last three letters': 'ara'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'bhi'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'dhy'}, 'M'),
#  ({'last three letters': 'hya'}, 'F'),
#  ({'last three letters': 'raf'}, 'M'),
#  ({'last three letters': 'aiz'}, 'M'),
#  ({'last three letters': 'ral'}, 'F'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'ran'}, 'M'),
#  ({'last three letters': 'nya'}, 'F'),
#  ({'last three letters': 'aon'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'rav'}, 'M'),
#  ({'last three letters': 'avi'}, 'F'),
#  ({'last three letters': 'ddy'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'ren'}, 'F'),
#  ({'last three letters': 'ren'}, 'M'),
#  ({'last three letters': 'eon'}, 'F'),
#  ({'last three letters': 'eon'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'ari'}, 'F'),
#  ({'last three letters': 'ari'}, 'M'),
#  ({'last three letters': 'ria'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'ian'}, 'F'),
#  ({'last three letters': 'ian'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'rib'}, 'M'),
#  ({'last three letters': 'ric'}, 'M'),
#  ({'last three letters': 'ica'}, 'F'),
#  ({'last three letters': 'ick'}, 'M'),
#  ({'last three letters': 'rie'}, 'F'),
#  ({'last three letters': 'iel'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'ien'}, 'M'),
#  ({'last three letters': 'rik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'eth'}, 'M'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'rin'}, 'F'),
#  ({'last three letters': 'rin'}, 'M'),
#  ({'last three letters': 'ini'}, 'F'),
#  ({'last three letters': 'ion'}, 'F'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'ris'}, 'F'),
#  ({'last three letters': 'ris'}, 'M'),
#  ({'last three letters': 'ish'}, 'M'),
#  ({'last three letters': 'rit'}, 'M'),
#  ({'last three letters': 'riv'}, 'M'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'riz'}, 'M'),
#  ({'last three letters': 'jav'}, 'M'),
#  ({'last three letters': 'arn'}, 'M'),
#  ({'last three letters': 'rna'}, 'F'),
#  ({'last three letters': 'nav'}, 'M'),
#  ({'last three letters': 'avi'}, 'F'),
#  ({'last three letters': 'rne'}, 'M'),
#  ({'last three letters': 'nik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'aro'}, 'M'),
#  ({'last three letters': 'roh'}, 'M'),
#  ({'last three letters': 'han'}, 'M'),
#  ({'last three letters': 'ohi'}, 'F'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'ron'}, 'F'),
#  ({'last three letters': 'ron'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'nae'}, 'F'),
#  ({'last three letters': 'nda'}, 'F'),
#  ({'last three letters': 'tte'}, 'F'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'cob'}, 'M'),
#  ({'last three letters': 'mes'}, 'M'),
#  ({'last three letters': 'ohn'}, 'M'),
#  ({'last three letters': 'eph'}, 'M'),
#  ({'last three letters': 'osh'}, 'M'),
#  ({'last three letters': 'hua'}, 'M'),
#  ({'last three letters': 'lee'}, 'M'),
#  ({'last three letters': 'ael'}, 'M'),
#  ({'last three letters': 'onn'}, 'M'),
#  ({'last three letters': 'osh'}, 'M'),
#  ({'last three letters': 'ren'}, 'M'),
#  ({'last three letters': 'ron'}, 'M'),
#  ({'last three letters': 'rsh'}, 'M'),
#  ({'last three letters': 'shi'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'thi'}, 'F'),
#  ({'last three letters': 'rti'}, 'F'),
#  ({'last three letters': 'uhi'}, 'F'),
#  ({'last three letters': 'nya'}, 'F'),
#  ({'last three letters': 'ush'}, 'M'),
#  ({'last three letters': 'shi'}, 'F'),
#  ({'last three letters': 'ddy'}, 'M'),
#  ({'last three letters': 'rvi'}, 'F'),
#  ({'last three letters': 'vik'}, 'M'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'vin'}, 'M'),
#  ({'last three letters': 'ary'}, 'M'),
#  ({'last three letters': 'rya'}, 'F'),
#  ({'last three letters': 'rya'}, 'M'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ahi'}, 'F'),
#  ({'last three letters': 'yan'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'nsh'}, 'M'),
#  ({'last three letters': 'ash'}, 'M'),
#  ({'last three letters': 'yav'}, 'M'),
#  ({'last three letters': 'ryn'}, 'F'),
#  ({'last three letters': 'ryn'}, 'M'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'yon'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'rza'}, 'F'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'ser'}, 'M'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'hay'}, 'M'),
#  ({'last three letters': 'her'}, 'M'),
#  ({'last three letters': 'shi'}, 'F'),
#  ({'last three letters': 'hia'}, 'F'),
#  ({'last three letters': 'ika'}, 'F'),
#  ({'last three letters': 'ini'}, 'F'),
#  ({'last three letters': 'hir'}, 'M'),
#  ({'last three letters': 'rya'}, 'F'),
#  ({'last three letters': 'ish'}, 'M'),
#  ({'last three letters': 'ita'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'hka'}, 'F'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'hna'}, 'F'),
#  ({'last three letters': 'hni'}, 'F'),
#  ({'last three letters': 'ray'}, 'M'),
#  ({'last three letters': 'rit'}, 'M'),
#  ({'last three letters': 'ita'}, 'F'),
#  ({'last three letters': 'ith'}, 'M'),
#  ({'last three letters': 'tha'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'hvi'}, 'F'),
#  ({'last three letters': 'vik'}, 'M'),
#  ({'last three letters': 'sia'}, 'F'),
#  ({'last three letters': 'iah'}, 'M'),
#  ({'last three letters': 'sim'}, 'M'),
#  ({'last three letters': 'sin'}, 'M'),
#  ({'last three letters': 'sir'}, 'M'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'son'}, 'M'),
#  ({'last three letters': 'tha'}, 'F'),
#  ({'last three letters': 'han'}, 'M'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'tif'}, 'M'),
#  ({'last three letters': 'kah'}, 'F'),
#  ({'last three letters': 'ish'}, 'M'),
#  ({'last three letters': 'ava'}, 'F'),
#  ({'last three letters': 'vah'}, 'F'),
#  ({'last three letters': 'van'}, 'M'),
#  ({'last three letters': 'ani'}, 'F'),
#  ({'last three letters': 'ash'}, 'M'),
#  ({'last three letters': 'ven'}, 'M'),
#  ({'last three letters': 'avi'}, 'M'),
#  ({'last three letters': 'vin'}, 'M'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'vir'}, 'M'),
#  ({'last three letters': 'ish'}, 'M'),
#  ({'last three letters': 'vya'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'vyn'}, 'F'),
#  ({'last three letters': 'vyn'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'aan'}, 'M'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yam'}, 'M'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nah'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'nsh'}, 'M'),
#  ({'last three letters': 'yat'}, 'F'),
#  ({'last three letters': 'dan'}, 'M'),
#  ({'last three letters': 'den'}, 'F'),
#  ({'last three letters': 'den'}, 'M'),
#  ({'last three letters': 'yla'}, 'F'),
#  ({'last three letters': 'lah'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'yon'}, 'M'),
#  ({'last three letters': 'yra'}, 'F'),
#  ({'last three letters': 'ayu'}, 'M'),
#  ({'last three letters': 'ush'}, 'M'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'shi'}, 'F'),
#  ({'last three letters': 'zan'}, 'M'),
#  ({'last three letters': 'een'}, 'F'),
#  ({'last three letters': 'zil'}, 'M'),
#  ({'last three letters': 'zim'}, 'M'),
#  ({'last three letters': 'zir'}, 'M'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'Ab'}, 'M'),
#  ({'last three letters': 'Aba'}, 'F'),
#  ({'last three letters': 'Aba'}, 'M'),
#  ({'last three letters': 'aan'}, 'M'),
#  ({'last three letters': 'aas'}, 'M'),
#  ({'last three letters': 'bad'}, 'M'),
#  ({'last three letters': 'don'}, 'M'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ile'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'eal'}, 'F'),
#  ({'last three letters': 'ban'}, 'M'),
#  ({'last three letters': 'oub'}, 'M'),
#  ({'last three letters': 'bas'}, 'M'),
#  ({'last three letters': 'asi'}, 'M'),
#  ({'last three letters': 'ass'}, 'M'),
#  ({'last three letters': 'omi'}, 'M'),
#  ({'last three letters': 'Abb'}, 'M'),
#  ({'last three letters': 'bba'}, 'F'),
#  ({'last three letters': 'bba'}, 'M'),
#  ({'last three letters': 'aas'}, 'M'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'bas'}, 'M'),
#  ({'last three letters': 'bbe'}, 'F'),
#  ({'last three letters': 'bee'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'bey'}, 'F'),
#  ({'last three letters': 'bey'}, 'M'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'bbi'}, 'F'),
#  ({'last three letters': 'bie'}, 'F'),
#  ({'last three letters': 'bie'}, 'M'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ail'}, 'M'),
#  ({'last three letters': 'ile'}, 'F'),
#  ({'last three letters': 'gal'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'ayl'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'bot'}, 'M'),
#  ({'last three letters': 'ott'}, 'F'),
#  ({'last three letters': 'ott'}, 'M'),
#  ({'last three letters': 'bra'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'bby'}, 'F'),
#  ({'last three letters': 'bby'}, 'M'),
#  ({'last three letters': 'bye'}, 'F'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ile'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'ayl'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'cde'}, 'F'),
#  ({'last three letters': 'Abd'}, 'M'),
#  ({'last three letters': 'ala'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'lla'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'del'}, 'M'),
#  ({'last three letters': 'ziz'}, 'M'),
#  ({'last three letters': 'adi'}, 'M'),
#  ({'last three letters': 'mid'}, 'M'),
#  ({'last three letters': 'der'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'rim'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'bdi'}, 'F'),
#  ({'last three letters': 'bdi'}, 'M'),
#  ({'last three letters': 'dia'}, 'F'),
#  ({'last three letters': 'ias'}, 'M'),
#  ({'last three letters': 'sis'}, 'M'),
#  ({'last three letters': 'ziz'}, 'M'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'tah'}, 'M'),
#  ({'last three letters': 'fid'}, 'M'),
#  ({'last three letters': 'kim'}, 'M'),
#  ({'last three letters': 'mid'}, 'M'),
#  ({'last three letters': 'dir'}, 'M'),
#  ({'last three letters': 'rim'}, 'M'),
#  ({'last three letters': 'liq'}, 'M'),
#  ({'last three letters': 'ahi'}, 'M'),
#  ({'last three letters': 'lik'}, 'M'),
#  ({'last three letters': 'jib'}, 'M'),
#  ({'last three letters': 'sir'}, 'M'),
#  ({'last three letters': 'ani'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'hin'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'hid'}, 'M'),
#  ({'last three letters': 'saq'}, 'M'),
#  ({'last three letters': 'zak'}, 'M'),
#  ({'last three letters': 'zaq'}, 'M'),
#  ({'last three letters': 'lam'}, 'M'),
#  ({'last three letters': 'lan'}, 'M'),
#  ({'last three letters': 'mad'}, 'M'),
#  ({'last three letters': 'kur'}, 'M'),
#  ({'last three letters': 'hab'}, 'M'),
#  ({'last three letters': 'ali'}, 'M'),
#  ({'last three letters': 'bdo'}, 'M'),
#  ({'last three letters': 'don'}, 'M'),
#  ({'last three letters': 'dou'}, 'M'),
#  ({'last three letters': 'oul'}, 'M'),
#  ({'last three letters': 'aye'}, 'M'),
#  ({'last three letters': 'ziz'}, 'M'),
#  ({'last three letters': 'lie'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'ane'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'rew'}, 'M'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'bdu'}, 'M'),
#  ({'last three letters': 'ual'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'uel'}, 'M'),
#  ({'last three letters': 'dul'}, 'M'),
#  ({'last three letters': 'ula'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'had'}, 'M'),
#  ({'last three letters': 'ahi'}, 'M'),
#  ({'last three letters': 'lai'}, 'M'),
#  ({'last three letters': 'aye'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'eez'}, 'M'),
#  ({'last three letters': 'zim'}, 'M'),
#  ({'last three letters': 'ziz'}, 'M'),
#  ({'last three letters': 'ari'}, 'M'),
#  ({'last three letters': 'sit'}, 'M'),
#  ({'last three letters': 'ule'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'ani'}, 'M'),
#  ({'last three letters': 'adi'}, 'M'),
#  ({'last three letters': 'adi'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'kim'}, 'M'),
#  ({'last three letters': 'lim'}, 'M'),
#  ({'last three letters': 'eed'}, 'M'),
#  ({'last three letters': 'mid'}, 'M'),
#  ({'last three letters': 'bar'}, 'M'),
#  ({'last three letters': 'eel'}, 'M'),
#  ({'last three letters': 'lil'}, 'M'),
#  ({'last three letters': 'dir'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'rim'}, 'M'),
#  ({'last three letters': 'liq'}, 'M'),
#  ({'last three letters': 'ull'}, 'M'),
#  ({'last three letters': 'lla'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'ahi'}, 'M'),
#  ({'last three letters': 'eef'}, 'M'),
#  ({'last three letters': 'tif'}, 'M'),
#  ({'last three letters': 'loh'}, 'M'),
#  ({'last three letters': 'eed'}, 'M'),
#  ({'last three letters': 'jid'}, 'M'),
#  ({'last three letters': 'lek'}, 'M'),
#  ({'last three letters': 'lik'}, 'M'),
#  ({'last three letters': 'nan'}, 'M'),
#  ({'last three letters': 'sen'}, 'M'),
#  ({'last three letters': 'sir'}, 'M'),
#  ({'last three letters': 'dir'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'zaq'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'lam'}, 'M'),
#  ({'last three letters': 'mad'}, 'M'),
#  ({'last three letters': 'dud'}, 'M'),
#  ({'last three letters': 'hab'}, 'M'),
#  ({'last three letters': 'hab'}, 'M'),
#  ({'last three letters': 'hid'}, 'M'),
#  ({'last three letters': 'ali'}, 'M'),
#  ({'last three letters': 'dur'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'mon'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'aan'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'mad'}, 'M'),
#  ({'last three letters': 'Abe'}, 'M'),
#  ({'last three letters': 'eal'}, 'M'),
#  ({'last three letters': 'bed'}, 'M'),
#  ({'last three letters': 'lah'}, 'M'),
#  ({'last three letters': 'man'}, 'M'),
#  ({'last three letters': 'ego'}, 'M'),
#  ({'last three letters': 'eha'}, 'F'),
#  ({'last three letters': 'eer'}, 'F'),
#  ({'last three letters': 'eer'}, 'M'),
#  ({'last three letters': 'era'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'bel'}, 'F'),
#  ({'last three letters': 'bel'}, 'M'),
#  ({'last three letters': 'ela'}, 'F'),
#  ({'last three letters': 'rdo'}, 'M'),
#  ({'last three letters': 'ina'}, 'F'),
#  ({'last three letters': 'ino'}, 'M'),
#  ({'last three letters': 'ell'}, 'F'),
#  ({'last three letters': 'ell'}, 'M'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'bem'}, 'M'),
#  ({'last three letters': 'ben'}, 'M'),
#  ({'last three letters': 'ena'}, 'F'),
#  ({'last three letters': 'zer'}, 'M'),
#  ({'last three letters': 'eni'}, 'F'),
#  ({'last three letters': 'ber'}, 'F'),
#  ({'last three letters': 'een'}, 'F'),
#  ({'last three letters': 'ham'}, 'M'),
#  ({'last three letters': 'thy'}, 'F'),
#  ({'last three letters': 'ert'}, 'M'),
#  ({'last three letters': 'ery'}, 'F'),
#  ({'last three letters': 'bey'}, 'F'),
#  ({'last three letters': 'bey'}, 'M'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'bha'}, 'F'),
#  ({'last three letters': 'hay'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'eek'}, 'M'),
#  ({'last three letters': 'bhi'}, 'M'),
#  ({'last three letters': 'gna'}, 'F'),
#  ({'last three letters': 'jay'}, 'M'),
#  ({'last three letters': 'eet'}, 'M'),
#  ({'last three letters': 'jit'}, 'M'),
#  ({'last three letters': 'jot'}, 'M'),
#  ({'last three letters': 'hik'}, 'M'),
#  ({'last three letters': 'ash'}, 'M'),
#  ({'last three letters': 'nyu'}, 'M'),
#  ({'last three letters': 'nav'}, 'M'),
#  ({'last three letters': 'nay'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'hir'}, 'M'),
#  ({'last three letters': 'aam'}, 'M'),
#  ({'last three letters': 'raj'}, 'M'),
#  ({'last three letters': 'ram'}, 'M'),
#  ({'last three letters': 'ami'}, 'F'),
#  ({'last three letters': 'rup'}, 'M'),
#  ({'last three letters': 'hek'}, 'M'),
#  ({'last three letters': 'ant'}, 'M'),
#  ({'last three letters': 'day'}, 'M'),
#  ({'last three letters': 'Abi'}, 'F'),
#  ({'last three letters': 'Abi'}, 'M'),
#  ({'last three letters': 'bia'}, 'F'),
#  ({'last three letters': 'eal'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'iah'}, 'M'),
#  ({'last three letters': 'ian'}, 'M'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'bid'}, 'M'),
#  ({'last three letters': 'ida'}, 'F'),
#  ({'last three letters': 'dah'}, 'F'),
#  ({'last three letters': 'dan'}, 'M'),
#  ({'last three letters': 'bie'}, 'F'),
#  ({'last three letters': 'bie'}, 'M'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'iel'}, 'F'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'ela'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'zer'}, 'M'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ael'}, 'M'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'hil'}, 'F'),
#  ({'last three letters': 'gai'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ail'}, 'M'),
#  ({'last three letters': 'ile'}, 'F'),
#  ({'last three letters': 'ace'}, 'F'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'rie'}, 'F'),
#  ({'last three letters': 'ose'}, 'F'),
#  ({'last three letters': 'gal'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yil'}, 'F'),
#  ({'last three letters': 'ayl'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'yle'}, 'M'),
#  ({'last three letters': 'eal'}, 'F'),
#  ({'last three letters': 'gel'}, 'F'),
#  ({'last three letters': 'ial'}, 'F'),
#  ({'last three letters': 'iha'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'jah'}, 'F'),
#  ({'last three letters': 'jah'}, 'M'),
#  ({'last three letters': 'ene'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'lio'}, 'M'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'ael'}, 'M'),
#  ({'last three letters': 'ola'}, 'F'),
#  ({'last three letters': 'ola'}, 'M'),
#  ({'last three letters': 'lec'}, 'M'),
#  ({'last three letters': 'bin'}, 'M'),
#  ({'last three letters': 'dab'}, 'M'),
#  ({'last three letters': 'adi'}, 'M'),
#  ({'last three letters': 'nav'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'dun'}, 'M'),
#  ({'last three letters': 'ola'}, 'F'),
#  ({'last three letters': 'ola'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'bir'}, 'F'),
#  ({'last three letters': 'bir'}, 'M'),
#  ({'last three letters': 'ira'}, 'F'),
#  ({'last three letters': 'ram'}, 'M'),
#  ({'last three letters': 'ami'}, 'F'),
#  ({'last three letters': 'sag'}, 'F'),
#  ({'last three letters': 'sai'}, 'F'),
#  ({'last three letters': 'sai'}, 'M'),
#  ({'last three letters': 'aid'}, 'M'),
#  ({'last three letters': 'ish'}, 'F'),
#  ({'last three letters': 'sha'}, 'F'),
#  ({'last three letters': 'hai'}, 'F'),
#  ({'last three letters': 'hai'}, 'M'),
#  ({'last three letters': 'hek'}, 'M'),
#  ({'last three letters': 'ola'}, 'F'),
#  ({'last three letters': 'iud'}, 'M'),
#  ({'last three letters': 'biy'}, 'M'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'yah'}, 'M'),
#  ({'last three letters': 'bla'}, 'F'),
#  ({'last three letters': 'kat'}, 'F'),
#  ({'last three letters': 'ble'}, 'M'),
#  ({'last three letters': 'nel'}, 'M'),
#  ({'last three letters': 'ner'}, 'M'),
#  ({'last three letters': 'ney'}, 'F'),
#  ({'last three letters': 'ney'}, 'M'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'ony'}, 'F'),
#  ({'last three letters': 'bou'}, 'M'),
#  ({'last three letters': 'car'}, 'M'),
#  ({'last three letters': 'kar'}, 'M'),
#  ({'last three letters': 'bra'}, 'F'),
#  ({'last three letters': 'aam'}, 'M'),
#  ({'last three letters': 'aar'}, 'M'),
#  ({'last three letters': 'rah'}, 'F'),
#  ({'last three letters': 'ham'}, 'F'),
#  ({'last three letters': 'ham'}, 'M'),
#  ({'last three letters': 'han'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'hem'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'ahm'}, 'M'),
#  ({'last three letters': 'ram'}, 'M'),
#  ({'last three letters': 'ams'}, 'M'),
#  ({'last three letters': 'ran'}, 'M'),
#  ({'last three letters': 'nda'}, 'F'),
#  ({'last three letters': 'rar'}, 'F'),
#  ({'last three letters': 'rar'}, 'M'),
#  ({'last three letters': 'xas'}, 'F'),
#  ({'last three letters': 'xas'}, 'M'),
#  ({'last three letters': 'aya'}, 'F'),
#  ({'last three letters': 'rea'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'ree'}, 'F'),
#  ({'last three letters': 'eia'}, 'F'),
#  ({'last three letters': 'rem'}, 'M'),
#  ({'last three letters': 'ren'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'rey'}, 'F'),
#  ({'last three letters': 'eya'}, 'F'),
#  ({'last three letters': 'ham'}, 'M'),
#  ({'last three letters': 'bri'}, 'F'),
#  ({'last three letters': 'ria'}, 'F'),
#  ({'last three letters': 'iah'}, 'F'),
#  ({'last three letters': 'ial'}, 'F'),
#  ({'last three letters': 'iam'}, 'M'),
#  ({'last three letters': 'ian'}, 'F'),
#  ({'last three letters': 'ian'}, 'M'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'nah'}, 'F'),
#  ({'last three letters': 'nne'}, 'F'),
#  ({'last three letters': 'rie'}, 'F'),
#  ({'last three letters': 'iel'}, 'F'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'ela'}, 'F'),
#  ({'last three letters': 'ele'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'ien'}, 'M'),
#  ({'last three letters': 'nne'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'het'}, 'F'),
#  ({'last three letters': 'ril'}, 'F'),
#  ({'last three letters': 'ril'}, 'M'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'ina'}, 'F'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'ona'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'ish'}, 'F'),
#  ({'last three letters': 'iya'}, 'F'),
#  ({'last three letters': 'yah'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'rom'}, 'M'),
#  ({'last three letters': 'ron'}, 'M'),
#  ({'last three letters': 'rum'}, 'M'),
#  ({'last three letters': 'bry'}, 'F'),
#  ({'last three letters': 'ana'}, 'F'),
#  ({'last three letters': 'nna'}, 'F'),
#  ({'last three letters': 'lla'}, 'F'),
#  ({'last three letters': 'lle'}, 'F'),
#  ({'last three letters': 'ryl'}, 'F'),
#  ({'last three letters': 'lat'}, 'F'),
#  ({'last three letters': 'lom'}, 'M'),
#  ({'last three letters': 'lon'}, 'M'),
#  ({'last three letters': 'hir'}, 'M'),
#  ({'last three letters': 'idy'}, 'F'),
#  ({'last three letters': 'tin'}, 'M'),
#  ({'last three letters': 'Abu'}, 'M'),
#  ({'last three letters': 'car'}, 'M'),
#  ({'last three letters': 'arr'}, 'M'),
#  ({'last three letters': 'kar'}, 'M'),
#  ({'last three letters': 'arr'}, 'M'),
#  ({'last three letters': 'ary'}, 'M'),
#  ({'last three letters': 'ker'}, 'M'),
#  ({'last three letters': 'kir'}, 'M'),
#  ({'last three letters': 'akr'}, 'M'),
#  ({'last three letters': 'buk'}, 'F'),
#  ({'last three letters': 'kar'}, 'M'),
#  ({'last three letters': 'dio'}, 'M'),
#  ({'last three letters': 'zar'}, 'M'),
#  ({'last three letters': 'Aby'}, 'F'),
#  ({'last three letters': 'Aby'}, 'M'),
#  ({'last three letters': 'ade'}, 'F'),
#  ({'last three letters': 'yan'}, 'F'),
#  ({'last three letters': 'yan'}, 'M'),
#  ({'last three letters': 'ael'}, 'F'),
#  ({'last three letters': 'ail'}, 'F'),
#  ({'last three letters': 'ile'}, 'F'),
#  ({'last three letters': 'ale'}, 'F'),
#  ({'last three letters': 'yle'}, 'F'),
#  ({'last three letters': 'nia'}, 'F'),
#  ({'last three letters': 'Ac'}, 'M'),
#  ({'last three letters': 'cia'}, 'F'),
#  ({'last three letters': 'ius'}, 'M'),
#  ({'last three letters': 'dia'}, 'F'),
#  ({'last three letters': 'cai'}, 'F'),
#  ({'last three letters': 'cai'}, 'M'),
#  ({'last three letters': 'mas'}, 'M'),
#  ({'last three letters': 'ari'}, 'F'),
#  ({'last three letters': 'ari'}, 'M'),
#  ({'last three letters': 'sia'}, 'F'),
#  ({'last three letters': 'cia'}, 'F'),
#  ({'last three letters': 'lia'}, 'F'),
#  ({'last three letters': 'ess'}, 'M'),
#  ({'last three letters': 'cie'}, 'M'),
#  ({'last three letters': 'sio'}, 'M'),
#  ({'last three letters': 'Ace'}, 'F'),
#  ({'last three letters': 'Ace'}, 'M'),
#  ({'last three letters': 'cea'}, 'F'),
#  ({'last three letters': 'cea'}, 'M'),
#  ({'last three letters': 'cee'}, 'M'),
#  ({'last three letters': 'ein'}, 'M'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'cel'}, 'M'),
#  ({'last three letters': 'lee'}, 'F'),
#  ({'last three letters': 'lia'}, 'F'),
#  ({'last three letters': 'lin'}, 'F'),
#  ({'last three letters': 'lin'}, 'M'),
#  ({'last three letters': 'ino'}, 'M'),
#  ({'last three letters': 'lyn'}, 'F'),
#  ({'last three letters': 'lyn'}, 'M'),
#  ({'last three letters': 'ynn'}, 'F'),
#  ({'last three letters': 'cen'}, 'M'),
#  ({'last three letters': 'ion'}, 'M'),
#  ({'last three letters': 'eon'}, 'M'),
#  ({'last three letters': 'cer'}, 'M'),
#  ({'last three letters': 'sen'}, 'M'),
#  ({'last three letters': 'son'}, 'M'),
#  ({'last three letters': 'ton'}, 'M'),
#  ({'last three letters': 'syn'}, 'M'),
#  ({'last three letters': 'ton'}, 'M'),
#  ({'last three letters': 'tyn'}, 'M'),
#  ({'last three letters': 'cey'}, 'F'),
#  ({'last three letters': 'cey'}, 'M'),
#  ({'last three letters': 'eyn'}, 'M'),
#  ({'last three letters': 'yon'}, 'M'),
#  ({'last three letters': 'hai'}, 'M'),
#  ({'last three letters': 'aia'}, 'F'),
#  ({'last three letters': 'ius'}, 'M'),
#  ({'last three letters': 'han'}, 'F'),
#  ({'last three letters': 'nte'}, 'F'),
#  ({'last three letters': 'nti'}, 'F'),
#  ({'last three letters': 'ary'}, 'M'),
#  ({'last three letters': 'zia'}, 'F'),
#  ({'last three letters': 'hel'}, 'F'),
#  ({'last three letters': 'ron'}, 'M'),
#  ({'last three letters': 'lle'}, 'M'),
#  ({'last three letters': 'eas'}, 'M'),
#  ({'last three letters': 'les'}, 'M'),
#  ({'last three letters': 'eus'}, 'M'),
#  ({'last three letters': 'ies'}, 'M'),
#  ({'last three letters': 'him'}, 'M'),
#  ({'last three letters': 'tya'}, 'M'),
#  ({'last three letters': 'hol'}, 'F'),
#  ({'last three letters': 'raf'}, 'M'),
#  ({'last three letters': 'hsa'}, 'F'),
#  ({'last three letters': 'sah'}, 'F'),
#  ({'last three letters': 'yut'}, 'M'),
#  ({'last three letters': 'uth'}, 'M'),
#  ({'last three letters': 'cia'}, 'F'),
#  ({'last three letters': 'ano'}, 'M'),
#  ({'last three letters': 'cie'}, 'F'),
#  ({'last three letters': 'cie'}, 'M'),
#  ({'last three letters': 'iel'}, 'M'),
#  ({'last three letters': 'cil'}, 'M'),
#  ({'last three letters': 'ire'}, 'F'),
#  ({'last three letters': 'ire'}, 'M'),
#  ({'last three letters': 'eem'}, 'M'),
#  ({'last three letters': 'ley'}, 'F'),
#  ({'last three letters': 'ley'}, 'M'),
#  ({'last three letters': 'cob'}, 'M'),
#  ({'last three letters': 'tta'}, 'F'),
#  ({'last three letters': 'tte'}, 'F'),
#  ({'last three letters': 'cre'}, 'M'),
#  ({'last three letters': 'csa'}, 'F'),
#  ...]

# %% [markdown]
# # Step 2: Instantiate NLTK Naive Bayes Classification Model & Train Model Using Preprocessed US Social Security Name-Gender Data

# %%
classifier = nltk.NaiveBayesClassifier.train(featuresets)

# %% [markdown]
# # Step 3: Preprocess NLTK Name-Gender Data to Test NLTK Naive Bayes Classification Model
# #### Notes
# * Although this name-gender data comes with the installation of the NLTK library, it does not come in the required format to be fed into the NLTK NBCM, so preprocessing is necessary
# * This is the same data passed to the RNF function via its 'df_test' parameter (same data used to test RNF function)

# %%
# Performing itertuples() method on every row from rnf_final DF for easier looping and extracting all of it into list
accuracy_list_1 = []
for item in rnf_final.itertuples():
    if item.Evaluation == "I":
        accuracy_list_1.append(item)
    elif item.Evaluation == "C":
        accuracy_list_1.append(item)

# %%
accuracy_list_1
# Out:
# [Pandas(Index=0, first_name='Aamir', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=1, first_name='Aaron', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=2, first_name='Abagael', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=3, first_name='Abagail', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=4, first_name='Abbe', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=5, first_name='Abbey', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=6, first_name='Abbey', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=7, first_name='Abbi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=8, first_name='Abbie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=9, first_name='Abbie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=10, first_name='Abbot', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=11, first_name='Abbott', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=12, first_name='Abby', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=13, first_name='Abby', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=14, first_name='Abdel', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=15, first_name='Abdul', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=16, first_name='Abdulkarim', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=17, first_name='Abdullah', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=18, first_name='Abe', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=19, first_name='Abel', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=20, first_name='Abelard', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=21, first_name='Abigael', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=22, first_name='Abigail', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=23, first_name='Abigale', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=24, first_name='Abner', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=25, first_name='Abra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=26, first_name='Abraham', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=27, first_name='Abram', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=28, first_name='Acacia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=29, first_name='Ace', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=30, first_name='Ada', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=31, first_name='Adah', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=32, first_name='Adair', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=33, first_name='Adaline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=34, first_name='Adam', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=35, first_name='Adams', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=36, first_name='Adara', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=37, first_name='Addie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=38, first_name='Addie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=39, first_name='Addis', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=40, first_name='Adel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=41, first_name='Adela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=42, first_name='Adelaide', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=43, first_name='Adele', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=44, first_name='Adelice', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=45, first_name='Adelina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=46, first_name='Adelind', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=47, first_name='Adeline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=48, first_name='Adella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=49, first_name='Adelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=50, first_name='Adena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=51, first_name='Adey', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=52, first_name='Adger', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=53, first_name='Adi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=54, first_name='Adiana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=55, first_name='Adina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=56, first_name='Aditya', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=57, first_name='Adlai', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=58, first_name='Adnan', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=59, first_name='Adolf', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=60, first_name='Adolfo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=61, first_name='Adolph', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=62, first_name='Adolphe', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=63, first_name='Adolpho', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=64, first_name='Adolphus', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=65, first_name='Adora', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=66, first_name='Adore', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=67, first_name='Adoree', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=68, first_name='Adorne', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=69, first_name='Adrea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=70, first_name='Adria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=71, first_name='Adriaens', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=72, first_name='Adrian', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=73, first_name='Adrian', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=74, first_name='Adriana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=75, first_name='Adriane', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=76, first_name='Adrianna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=77, first_name='Adrianne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=78, first_name='Adrick', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=79, first_name='Adrien', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=80, first_name='Adrien', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=81, first_name='Adriena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=82, first_name='Adrienne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=83, first_name='Aeriel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=84, first_name='Aeriela', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=85, first_name='Aeriell', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=86, first_name='Ag', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=87, first_name='Agace', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=88, first_name='Agamemnon', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=89, first_name='Agata', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=90, first_name='Agatha', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=91, first_name='Agathe', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=92, first_name='Aggi', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=93, first_name='Aggie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=94, first_name='Aggy', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=95, first_name='Agna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=96, first_name='Agnella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=97, first_name='Agnes', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=98, first_name='Agnese', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=99, first_name='Agnesse', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=100, first_name='Agneta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=101, first_name='Agnola', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=102, first_name='Agretha', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=103, first_name='Aguinaldo', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=104, first_name='Aguste', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=105, first_name='Agustin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=106, first_name='Aharon', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=107, first_name='Ahmad', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=108, first_name='Ahmed', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=109, first_name='Ahmet', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=110, first_name='Aida', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=111, first_name='Aidan', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=112, first_name='Aigneis', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=113, first_name='Aila', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=114, first_name='Aile', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=115, first_name='Ailee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=116, first_name='Aileen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=117, first_name='Ailene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=118, first_name='Ailey', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=119, first_name='Aili', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=120, first_name='Ailina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=121, first_name='Ailyn', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=122, first_name='Aime', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=123, first_name='Aimee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=124, first_name='Aimil', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=125, first_name='Aina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=126, first_name='Aindrea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=127, first_name='Ainslee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=128, first_name='Ainsley', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=129, first_name='Ainslie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=130, first_name='Ajai', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=131, first_name='Ajay', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=132, first_name='Ajay', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=133, first_name='Al', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=134, first_name='Alaa', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=135, first_name='Alain', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=136, first_name='Alaine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=137, first_name='Alameda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=138, first_name='Alan', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=139, first_name='Alana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=140, first_name='Alanah', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=141, first_name='Alane', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=142, first_name='Alanna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=143, first_name='Alasdair', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=144, first_name='Alastair', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=145, first_name='Alayne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=146, first_name='Albatros', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=147, first_name='Albert', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=148, first_name='Alberta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=149, first_name='Albertina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=150, first_name='Albertine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=151, first_name='Alberto', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=152, first_name='Albina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=153, first_name='Albrecht', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=154, first_name='Alden', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=155, first_name='Aldis', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=156, first_name='Aldo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=157, first_name='Aldric', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=158, first_name='Aldrich', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=159, first_name='Aldus', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=160, first_name='Aldwin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=161, first_name='Alec', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=162, first_name='Alecia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=163, first_name='Aleck', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=164, first_name='Aleda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=165, first_name='Aleece', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=166, first_name='Aleecia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=167, first_name='Aleen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=168, first_name='Alejandra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=169, first_name='Alejandrina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=170, first_name='Alejandro', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=171, first_name='Aleks', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=172, first_name='Aleksandrs', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=173, first_name='Alena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=174, first_name='Alene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=175, first_name='Alessandra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=176, first_name='Alessandro', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=177, first_name='Aleta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=178, first_name='Alethea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=179, first_name='Alex', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=180, first_name='Alex', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=181, first_name='Alexa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=182, first_name='Alexander', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=183, first_name='Alexandra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=184, first_name='Alexandrina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=185, first_name='Alexei', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=186, first_name='Alexi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=187, first_name='Alexia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=188, first_name='Alexina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=189, first_name='Alexine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=190, first_name='Alexis', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=191, first_name='Alexis', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=192, first_name='Alf', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=193, first_name='Alfie', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=194, first_name='Alfie', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=195, first_name='Alfonse', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=196, first_name='Alfonso', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=197, first_name='Alfonzo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=198, first_name='Alford', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=199, first_name='Alfred', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=200, first_name='Alfreda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=201, first_name='Alfredo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=202, first_name='Algernon', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=203, first_name='Ali', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=204, first_name='Ali', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=205, first_name='Alia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=206, first_name='Alic', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=207, first_name='Alica', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=208, first_name='Alice', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=209, first_name='Alicea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=210, first_name='Alicia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=211, first_name='Alida', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=212, first_name='Alidia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=213, first_name='Alina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=214, first_name='Aline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=215, first_name='Alis', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=216, first_name='Alisa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=217, first_name='Alisha', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=218, first_name='Alison', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=219, first_name='Alissa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=220, first_name='Alister', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=221, first_name='Alisun', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=222, first_name='Alix', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=223, first_name='Alix', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=224, first_name='Aliza', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=225, first_name='Alla', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=226, first_name='Allah', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=227, first_name='Allan', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=228, first_name='Alleen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=229, first_name='Allegra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=230, first_name='Allen', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=231, first_name='Allene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=232, first_name='Alley', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=233, first_name='Alli', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=234, first_name='Allianora', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=235, first_name='Allie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=236, first_name='Allie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=237, first_name='Allin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=238, first_name='Allina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=239, first_name='Allis', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=240, first_name='Allison', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=241, first_name='Allissa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=242, first_name='Allsun', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=243, first_name='Ally', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=244, first_name='Allyce', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=245, first_name='Allyn', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=246, first_name='Allyn', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=247, first_name='Allys', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=248, first_name='Allyson', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=249, first_name='Alma', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=250, first_name='Almeda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=251, first_name='Almeria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=252, first_name='Almeta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=253, first_name='Almira', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=254, first_name='Almire', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=255, first_name='Aloise', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=256, first_name='Aloisia', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=257, first_name='Alonso', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=258, first_name='Alonzo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=259, first_name='Aloysia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=260, first_name='Aloysius', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=261, first_name='Alpa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=262, first_name='Alphonse', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=263, first_name='Alphonso', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=264, first_name='Alston', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=265, first_name='Alta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=266, first_name='Althea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=267, first_name='Alton', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=268, first_name='Alvera', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=269, first_name='Alvin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=270, first_name='Alvina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=271, first_name='Alvinia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=272, first_name='Alvira', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=273, first_name='Alwin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=274, first_name='Alyce', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=275, first_name='Alyda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=276, first_name='Alys', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=277, first_name='Alysa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=278, first_name='Alyse', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=279, first_name='Alysia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=280, first_name='Alyson', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=281, first_name='Alyss', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=282, first_name='Alyssa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=283, first_name='Amabel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=284, first_name='Amabelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=285, first_name='Amadeus', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=286, first_name='Amalea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=287, first_name='Amalee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=288, first_name='Amaleta', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=289, first_name='Amalia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=290, first_name='Amalie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=291, first_name='Amalita', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=292, first_name='Amalle', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=293, first_name='Amanda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=294, first_name='Amandi', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=295, first_name='Amandie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=296, first_name='Amandy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=297, first_name='Amara', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=298, first_name='Amargo', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=299, first_name='Amata', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=300, first_name='Amber', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=301, first_name='Amberly', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=302, first_name='Ambros', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=303, first_name='Ambrose', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=304, first_name='Ambrosi', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=305, first_name='Ambrosia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=306, first_name='Ambrosio', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=307, first_name='Ambrosius', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=308, first_name='Ambur', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=309, first_name='Ame', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=310, first_name='Amelia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=311, first_name='Amelie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=312, first_name='Amelina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=313, first_name='Ameline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=314, first_name='Amelita', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=315, first_name='Amery', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=316, first_name='Ami', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=317, first_name='Amie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=318, first_name='Amity', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=319, first_name='Ammamaria', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=320, first_name='Amory', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=321, first_name='Amos', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=322, first_name='Amy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=323, first_name='Ana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=324, first_name='Anabel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=325, first_name='Anabella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=326, first_name='Anabelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=327, first_name='Anais', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=328, first_name='Analiese', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=329, first_name='Analise', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=330, first_name='Anallese', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=331, first_name='Anallise', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=332, first_name='Anastasia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=333, first_name='Anastasie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=334, first_name='Anastassia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=335, first_name='Anatol', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=336, first_name='Anatola', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=337, first_name='Anatole', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=338, first_name='Anatollo', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=339, first_name='Anatoly', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=340, first_name='Andee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=341, first_name='Anders', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=342, first_name='Andi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=343, first_name='Andie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=344, first_name='Andie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=345, first_name='Andonis', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=346, first_name='Andra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=347, first_name='Andre', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=348, first_name='Andrea', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=349, first_name='Andrea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=350, first_name='Andreana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=351, first_name='Andreas', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=352, first_name='Andree', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=353, first_name='Andrei', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=354, first_name='Andrej', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=355, first_name='Andres', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=356, first_name='Andrew', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=357, first_name='Andrey', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=358, first_name='Andri', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=359, first_name='Andria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=360, first_name='Andriana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=361, first_name='Andriette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=362, first_name='Andromache', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=363, first_name='Andromeda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=364, first_name='Andros', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=365, first_name='Andrus', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=366, first_name='Andrzej', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=367, first_name='Andy', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=368, first_name='Andy', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=369, first_name='Anestassia', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=370, first_name='Anet', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=371, first_name='Anett', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=372, first_name='Anetta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=373, first_name='Anette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=374, first_name='Ange', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=375, first_name='Angel', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=376, first_name='Angel', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=377, first_name='Angela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=378, first_name='Angele', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=379, first_name='Angelia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=380, first_name='Angelica', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=381, first_name='Angelico', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=382, first_name='Angelika', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=383, first_name='Angelina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=384, first_name='Angeline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=385, first_name='Angelique', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=386, first_name='Angelita', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=387, first_name='Angelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=388, first_name='Angelo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=389, first_name='Angie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=390, first_name='Angie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=391, first_name='Angil', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=392, first_name='Angus', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=393, first_name='Angy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=394, first_name='Ania', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=395, first_name='Anica', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=396, first_name='Anissa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=397, first_name='Anita', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=398, first_name='Anitra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=399, first_name='Anja', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=400, first_name='Anjanette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=401, first_name='Anjela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=402, first_name='Ann', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=403, first_name='Ann-Mari', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=404, first_name='Ann-Marie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=405, first_name='Anna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=406, first_name='Anna-Diana', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=407, first_name='Anna-Diane', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=408, first_name='Anna-Maria', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=409, first_name='Annabal', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=410, first_name='Annabel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=411, first_name='Annabela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=412, first_name='Annabell', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=413, first_name='Annabella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=414, first_name='Annabelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=415, first_name='Annadiana', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=416, first_name='Annadiane', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=417, first_name='Annalee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=418, first_name='Annalena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=419, first_name='Annaliese', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=420, first_name='Annalisa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=421, first_name='Annalise', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=422, first_name='Annalyse', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=423, first_name='Annamari', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=424, first_name='Annamaria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=425, first_name='Annamarie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=426, first_name='Anne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=427, first_name='Anne-Corinne', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=428, first_name='Anne-Mar', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=429, first_name='Anne-Marie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=430, first_name='Annecorinne', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=431, first_name='Anneliese', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=432, first_name='Annelise', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=433, first_name='Annemarie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=434, first_name='Annetta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=435, first_name='Annette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=436, first_name='Anni', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=437, first_name='Annice', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=438, first_name='Annie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=439, first_name='Annissa', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=440, first_name='Annmaria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=441, first_name='Annmarie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=442, first_name='Annnora', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=443, first_name='Annora', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=444, first_name='Anny', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=445, first_name='Ansel', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=446, first_name='Ansell', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=447, first_name='Anselm', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=448, first_name='Anselma', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=449, first_name='Ansley', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=450, first_name='Anson', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=451, first_name='Anstice', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=452, first_name='Anthe', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=453, first_name='Anthea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=454, first_name='Anthia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=455, first_name='Anthony', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=456, first_name='Antin', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=457, first_name='Antoine', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=458, first_name='Antoinette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=459, first_name='Anton', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=460, first_name='Antone', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=461, first_name='Antonella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=462, first_name='Antonetta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=463, first_name='Antoni', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=464, first_name='Antonia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=465, first_name='Antonie', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=466, first_name='Antonietta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=467, first_name='Antonin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=468, first_name='Antonina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=469, first_name='Antonino', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=470, first_name='Antonio', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=471, first_name='Antonius', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=472, first_name='Antony', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=473, first_name='Anurag', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=474, first_name='Anya', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=475, first_name='Aphrodite', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=476, first_name='Apollo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=477, first_name='Apostolos', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=478, first_name='Appolonia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=479, first_name='April', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=480, first_name='Aprilette', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=481, first_name='Ara', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=482, first_name='Arabel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=483, first_name='Arabela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=484, first_name='Arabele', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=485, first_name='Arabella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=486, first_name='Arabelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=487, first_name='Aram', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=488, first_name='Archibald', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=489, first_name='Archibold', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=490, first_name='Archie', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=491, first_name='Archon', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=492, first_name='Archy', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=493, first_name='Arda', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=494, first_name='Ardath', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=495, first_name='Ardeen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=496, first_name='Ardelia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=497, first_name='Ardelis', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=498, first_name='Ardella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=499, first_name='Ardelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=500, first_name='Arden', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=501, first_name='Ardene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=502, first_name='Ardenia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=503, first_name='Ardine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=504, first_name='Ardis', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=505, first_name='Ardith', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=506, first_name='Ardra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=507, first_name='Ardyce', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=508, first_name='Ardys', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=509, first_name='Ardyth', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=510, first_name='Arel', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=511, first_name='Aretha', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=512, first_name='Ari', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=513, first_name='Ariadne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=514, first_name='Ariana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=515, first_name='Arianne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=516, first_name='Aridatha', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=517, first_name='Arie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=518, first_name='Ariel', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=519, first_name='Ariel', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=520, first_name='Ariela', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=521, first_name='Ariella', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=522, first_name='Arielle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=523, first_name='Aristotle', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=524, first_name='Arlana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=525, first_name='Arlee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=526, first_name='Arleen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=527, first_name='Arlen', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=528, first_name='Arlena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=529, first_name='Arlene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=530, first_name='Arleta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=531, first_name='Arlette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=532, first_name='Arleyne', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=533, first_name='Arlie', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=534, first_name='Arliene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=535, first_name='Arlina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=536, first_name='Arlinda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=537, first_name='Arline', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=538, first_name='Arlo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=539, first_name='Arly', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=540, first_name='Arlyn', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=541, first_name='Arlyne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=542, first_name='Armand', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=543, first_name='Armando', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=544, first_name='Armond', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=545, first_name='Armstrong', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=546, first_name='Arne', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=547, first_name='Arnie', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=548, first_name='Arnold', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=549, first_name='Arnoldo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=550, first_name='Aron', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=551, first_name='Arron', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=552, first_name='Art', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=553, first_name='Arther', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=554, first_name='Arthur', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=555, first_name='Artie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=556, first_name='Artur', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=557, first_name='Arturo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=558, first_name='Arvie', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=559, first_name='Arvin', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=560, first_name='Arvind', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=561, first_name='Arvy', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=562, first_name='Aryn', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=563, first_name='Ash', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=564, first_name='Ashby', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=565, first_name='Ashely', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=566, first_name='Ashish', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=567, first_name='Ashlee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=568, first_name='Ashleigh', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=569, first_name='Ashlen', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=570, first_name='Ashley', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=571, first_name='Ashley', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=572, first_name='Ashli', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=573, first_name='Ashlie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=574, first_name='Ashly', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=575, first_name='Ashton', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=576, first_name='Asia', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=577, first_name='Astra', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=578, first_name='Astrid', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=579, first_name='Astrix', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=580, first_name='Atalanta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=581, first_name='Athena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=582, first_name='Athene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=583, first_name='Atlanta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=584, first_name='Atlante', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=585, first_name='Aub', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=586, first_name='Aube', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=587, first_name='Aubert', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=588, first_name='Auberta', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=589, first_name='Aubine', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=590, first_name='Aubree', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=591, first_name='Aubrette', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=592, first_name='Aubrey', gender='F', Actual='M', Evaluation='I'),
# ...
#  Pandas(Index=803, first_name='Beret', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=804, first_name='Berget', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=805, first_name='Berk', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=806, first_name='Berke', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=807, first_name='Berkeley', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=808, first_name='Berkie', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=809, first_name='Berkley', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=810, first_name='Berna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=811, first_name='Bernadene', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=812, first_name='Bernadette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=813, first_name='Bernadina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=814, first_name='Bernadine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=815, first_name='Bernard', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=816, first_name='Bernardina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=817, first_name='Bernardine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=818, first_name='Bernardo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=819, first_name='Bernd', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=820, first_name='Bernelle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=821, first_name='Bernete', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=822, first_name='Bernetta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=823, first_name='Bernette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=824, first_name='Bernhard', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=825, first_name='Berni', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=826, first_name='Bernice', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=827, first_name='Bernie', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=828, first_name='Bernie', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=829, first_name='Bernita', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=830, first_name='Berny', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=831, first_name='Berri', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=832, first_name='Berrie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=833, first_name='Berry', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=834, first_name='Bert', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=835, first_name='Bert', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=836, first_name='Berta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=837, first_name='Berte', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=838, first_name='Bertha', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=839, first_name='Berthe', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=840, first_name='Berti', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=841, first_name='Bertie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=842, first_name='Bertie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=843, first_name='Bertina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=844, first_name='Bertine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=845, first_name='Bertram', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=846, first_name='Bertrand', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=847, first_name='Berty', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=848, first_name='Beryl', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=849, first_name='Beryle', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=850, first_name='Bess', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=851, first_name='Bessie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=852, first_name='Bessy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=853, first_name='Beth', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=854, first_name='Bethanne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=855, first_name='Bethany', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=856, first_name='Bethena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=857, first_name='Bethina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=858, first_name='Betsey', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=859, first_name='Betsy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=860, first_name='Betta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=861, first_name='Bette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=862, first_name='Bette-Ann', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=863, first_name='Betteann', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=864, first_name='Betteanne', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=865, first_name='Betti', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=866, first_name='Bettie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=867, first_name='Bettina', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=868, first_name='Bettine', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=869, first_name='Betty', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=870, first_name='Bettye', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=871, first_name='Beulah', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=872, first_name='Bev', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=873, first_name='Beverie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=874, first_name='Beverlee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=875, first_name='Beverlie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=876, first_name='Beverly', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=877, first_name='Bevvy', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=878, first_name='Bharat', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=879, first_name='Bianca', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=880, first_name='Bianka', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=881, first_name='Biddy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=882, first_name='Bidget', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=883, first_name='Biff', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=884, first_name='Bill', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=885, first_name='Bill', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=886, first_name='Billi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=887, first_name='Billie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=888, first_name='Billie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=889, first_name='Billy', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=890, first_name='Billy', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=891, first_name='Bing', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=892, first_name='Binky', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=893, first_name='Binni', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=894, first_name='Binnie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=895, first_name='Binny', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=896, first_name='Bird', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=897, first_name='Birdie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=898, first_name='Birgit', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=899, first_name='Birgitta', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=900, first_name='Bishop', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=901, first_name='Bjorn', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=902, first_name='Bjorne', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=903, first_name='Blaine', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=904, first_name='Blair', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=905, first_name='Blair', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=906, first_name='Blaire', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=907, first_name='Blake', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=908, first_name='Blake', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=909, first_name='Blakelee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=910, first_name='Blakeley', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=911, first_name='Blanca', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=912, first_name='Blanch', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=913, first_name='Blancha', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=914, first_name='Blanche', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=915, first_name='Blare', gender='U', Actual='M', Evaluation='I'),
#  Pandas(Index=916, first_name='Blayne', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=917, first_name='Blinni', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=918, first_name='Blinnie', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=919, first_name='Blinny', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=920, first_name='Bliss', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=921, first_name='Blisse', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=922, first_name='Blithe', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=923, first_name='Blondell', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=924, first_name='Blondelle', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=925, first_name='Blondie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=926, first_name='Blondy', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=927, first_name='Blythe', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=928, first_name='Bo', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=929, first_name='Bo', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=930, first_name='Bob', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=931, first_name='Bobbette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=932, first_name='Bobbi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=933, first_name='Bobbie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=934, first_name='Bobbie', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=935, first_name='Bobby', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=936, first_name='Bobby', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=937, first_name='Bobette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=938, first_name='Bobina', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=939, first_name='Bobine', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=940, first_name='Bobinette', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=941, first_name='Bogart', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=942, first_name='Bogdan', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=943, first_name='Boniface', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=944, first_name='Bonita', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=945, first_name='Bonnee', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=946, first_name='Bonni', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=947, first_name='Bonnie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=948, first_name='Bonny', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=949, first_name='Boris', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=950, first_name='Boyce', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=951, first_name='Boyd', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=952, first_name='Brad', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=953, first_name='Braden', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=954, first_name='Bradford', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=955, first_name='Bradley', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=956, first_name='Bradly', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=957, first_name='Brady', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=958, first_name='Brana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=959, first_name='Brandais', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=960, first_name='Brande', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=961, first_name='Brandea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=962, first_name='Brandi', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=963, first_name='Brandice', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=964, first_name='Brandie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=965, first_name='Brandise', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=966, first_name='Brandon', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=967, first_name='Brandy', gender='F', Actual='M', Evaluation='I'),
#  Pandas(Index=968, first_name='Brandy', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=969, first_name='Brant', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=970, first_name='Brea', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=971, first_name='Breanne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=972, first_name='Brear', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=973, first_name='Bree', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=974, first_name='Breena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=975, first_name='Bren', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=976, first_name='Brena', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=977, first_name='Brenda', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=978, first_name='Brendan', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=979, first_name='Brenn', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=980, first_name='Brenna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=981, first_name='Brent', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=982, first_name='Bret', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=983, first_name='Brett', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=984, first_name='Brett', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=985, first_name='Brewer', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=986, first_name='Brewster', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=987, first_name='Bria', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=988, first_name='Brian', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=989, first_name='Briana', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=990, first_name='Brianna', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=991, first_name='Brianne', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=992, first_name='Brice', gender='M', Actual='M', Evaluation='C'),
#  Pandas(Index=993, first_name='Bride', gender='U', Actual='F', Evaluation='I'),
#  Pandas(Index=994, first_name='Bridget', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=995, first_name='Bridgett', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=996, first_name='Bridgette', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=997, first_name='Bridie', gender='F', Actual='F', Evaluation='C'),
#  Pandas(Index=998, first_name='Brier', gender='M', Actual='F', Evaluation='I'),
#  Pandas(Index=999, first_name='Brietta', gender='F', Actual='F', Evaluation='C'),
#  ...]

# %%
# Creating a new list variable and extracting only the first names column from the list above and storing all of the first names in this new list
new_list = []

for names in accuracy_list_1:
    new_list.append(names[1])

new_list
# Out:
# ['Aamir',
#  'Aaron',
#  'Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abbie',
#  'Abbot',
#  'Abbott',
#  'Abby',
#  'Abby',
#  'Abdel',
#  'Abdul',
#  'Abdulkarim',
#  'Abdullah',
#  'Abe',
#  'Abel',
#  'Abelard',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abner',
#  'Abra',
#  'Abraham',
#  'Abram',
#  'Acacia',
#  'Ace',
#  'Ada',
#  'Adah',
#  'Adair',
#  'Adaline',
#  'Adam',
#  'Adams',
#  'Adara',
#  'Addie',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adger',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Aditya',
#  'Adlai',
#  'Adnan',
#  'Adolf',
#  'Adolfo',
#  'Adolph',
#  'Adolphe',
#  'Adolpho',
#  'Adolphus',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrick',
#  'Adrien',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agamemnon',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aguinaldo',
#  'Aguste',
#  'Agustin',
#  'Aharon',
#  'Ahmad',
#  'Ahmed',
#  'Ahmet',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
#  'Aime',
#  'Aimee',
#  'Aimil',
#  'Aina',
#  'Aindrea',
#  'Ainslee',
#  'Ainsley',
#  'Ainslie',
#  'Ajai',
#  'Ajay',
#  'Ajay',
#  'Al',
#  'Alaa',
#  'Alain',
#  'Alaine',
#  'Alameda',
#  'Alan',
#  'Alana',
#  'Alanah',
#  'Alane',
#  'Alanna',
#  'Alasdair',
#  'Alastair',
#  'Alayne',
#  'Albatros',
#  'Albert',
#  'Alberta',
#  'Albertina',
#  'Albertine',
#  'Alberto',
#  'Albina',
#  'Albrecht',
#  'Alden',
#  'Aldis',
#  'Aldo',
#  'Aldric',
#  'Aldrich',
#  'Aldus',
#  'Aldwin',
#  'Alec',
#  'Alecia',
#  'Aleck',
#  'Aleda',
#  'Aleece',
#  'Aleecia',
#  'Aleen',
#  'Alejandra',
#  'Alejandrina',
#  'Alejandro',
#  'Aleks',
#  'Aleksandrs',
#  'Alena',
#  'Alene',
#  'Alessandra',
#  'Alessandro',
#  'Aleta',
#  'Alethea',
#  'Alex',
#  'Alex',
#  'Alexa',
#  'Alexander',
#  'Alexandra',
#  'Alexandrina',
#  'Alexei',
#  'Alexi',
#  'Alexia',
#  'Alexina',
#  'Alexine',
#  'Alexis',
#  'Alexis',
#  'Alf',
#  'Alfie',
#  'Alfie',
#  'Alfonse',
#  'Alfonso',
#  'Alfonzo',
#  'Alford',
#  'Alfred',
#  'Alfreda',
#  'Alfredo',
#  'Algernon',
#  'Ali',
#  'Ali',
#  'Alia',
#  'Alic',
#  'Alica',
#  'Alice',
#  'Alicea',
#  'Alicia',
#  'Alida',
#  'Alidia',
#  'Alina',
#  'Aline',
#  'Alis',
#  'Alisa',
#  'Alisha',
#  'Alison',
#  'Alissa',
#  'Alister',
#  'Alisun',
#  'Alix',
#  'Alix',
#  'Aliza',
#  'Alla',
#  'Allah',
#  'Allan',
#  'Alleen',
#  'Allegra',
#  'Allen',
#  'Allene',
#  'Alley',
#  'Alli',
#  'Allianora',
#  'Allie',
#  'Allie',
#  'Allin',
#  'Allina',
#  'Allis',
#  'Allison',
#  'Allissa',
#  'Allsun',
#  'Ally',
#  'Allyce',
#  'Allyn',
#  'Allyn',
#  'Allys',
#  'Allyson',
#  'Alma',
#  'Almeda',
#  'Almeria',
#  'Almeta',
#  'Almira',
#  'Almire',
#  'Aloise',
#  'Aloisia',
#  'Alonso',
#  'Alonzo',
#  'Aloysia',
#  'Aloysius',
#  'Alpa',
#  'Alphonse',
#  'Alphonso',
#  'Alston',
#  'Alta',
#  'Althea',
#  'Alton',
#  'Alvera',
#  'Alvin',
#  'Alvina',
#  'Alvinia',
#  'Alvira',
#  'Alwin',
#  'Alyce',
#  'Alyda',
#  'Alys',
#  'Alysa',
#  'Alyse',
#  'Alysia',
#  'Alyson',
#  'Alyss',
#  'Alyssa',
#  'Amabel',
#  'Amabelle',
#  'Amadeus',
#  'Amalea',
#  'Amalee',
#  'Amaleta',
#  'Amalia',
#  'Amalie',
#  'Amalita',
#  'Amalle',
#  'Amanda',
#  'Amandi',
#  'Amandie',
#  'Amandy',
#  'Amara',
#  'Amargo',
#  'Amata',
#  'Amber',
#  'Amberly',
#  'Ambros',
#  'Ambrose',
#  'Ambrosi',
#  'Ambrosia',
#  'Ambrosio',
#  'Ambrosius',
#  'Ambur',
#  'Ame',
#  'Amelia',
#  'Amelie',
#  'Amelina',
#  'Ameline',
#  'Amelita',
#  'Amery',
#  'Ami',
#  'Amie',
#  'Amity',
#  'Ammamaria',
#  'Amory',
#  'Amos',
#  'Amy',
#  'Ana',
#  'Anabel',
#  'Anabella',
#  'Anabelle',
#  'Anais',
#  'Analiese',
#  'Analise',
#  'Anallese',
#  'Anallise',
#  'Anastasia',
#  'Anastasie',
#  'Anastassia',
#  'Anatol',
#  'Anatola',
#  'Anatole',
#  'Anatollo',
#  'Anatoly',
#  'Andee',
#  'Anders',
#  'Andi',
#  'Andie',
#  'Andie',
#  'Andonis',
#  'Andra',
#  'Andre',
#  'Andrea',
#  'Andrea',
#  'Andreana',
#  'Andreas',
#  'Andree',
#  'Andrei',
#  'Andrej',
#  'Andres',
#  'Andrew',
#  'Andrey',
#  'Andri',
#  'Andria',
#  'Andriana',
#  'Andriette',
#  'Andromache',
#  'Andromeda',
#  'Andros',
#  'Andrus',
#  'Andrzej',
#  'Andy',
#  'Andy',
#  'Anestassia',
#  'Anet',
#  'Anett',
#  'Anetta',
#  'Anette',
#  'Ange',
#  'Angel',
#  'Angel',
#  'Angela',
#  'Angele',
#  'Angelia',
#  'Angelica',
#  'Angelico',
#  'Angelika',
#  'Angelina',
#  'Angeline',
#  'Angelique',
#  'Angelita',
#  'Angelle',
#  'Angelo',
#  'Angie',
#  'Angie',
#  'Angil',
#  'Angus',
#  'Angy',
#  'Ania',
#  'Anica',
#  'Anissa',
#  'Anita',
#  'Anitra',
#  'Anja',
#  'Anjanette',
#  'Anjela',
#  'Ann',
#  'Ann-Mari',
#  'Ann-Marie',
#  'Anna',
#  'Anna-Diana',
#  'Anna-Diane',
#  'Anna-Maria',
#  'Annabal',
#  'Annabel',
#  'Annabela',
#  'Annabell',
#  'Annabella',
#  'Annabelle',
#  'Annadiana',
#  'Annadiane',
#  'Annalee',
#  'Annalena',
#  'Annaliese',
#  'Annalisa',
#  'Annalise',
#  'Annalyse',
#  'Annamari',
#  'Annamaria',
#  'Annamarie',
#  'Anne',
#  'Anne-Corinne',
#  'Anne-Mar',
#  'Anne-Marie',
#  'Annecorinne',
#  'Anneliese',
#  'Annelise',
#  'Annemarie',
#  'Annetta',
#  'Annette',
#  'Anni',
#  'Annice',
#  'Annie',
#  'Annissa',
#  'Annmaria',
#  'Annmarie',
#  'Annnora',
#  'Annora',
#  'Anny',
#  'Ansel',
#  'Ansell',
#  'Anselm',
#  'Anselma',
#  'Ansley',
#  'Anson',
#  'Anstice',
#  'Anthe',
#  'Anthea',
#  'Anthia',
#  'Anthony',
#  'Antin',
#  'Antoine',
#  'Antoinette',
#  'Anton',
#  'Antone',
#  'Antonella',
#  'Antonetta',
#  'Antoni',
#  'Antonia',
#  'Antonie',
#  'Antonietta',
#  'Antonin',
#  'Antonina',
#  'Antonino',
#  'Antonio',
#  'Antonius',
#  'Antony',
#  'Anurag',
#  'Anya',
#  'Aphrodite',
#  'Apollo',
#  'Apostolos',
#  'Appolonia',
#  'April',
#  'Aprilette',
#  'Ara',
#  'Arabel',
#  'Arabela',
#  'Arabele',
#  'Arabella',
#  'Arabelle',
#  'Aram',
#  'Archibald',
#  'Archibold',
#  'Archie',
#  'Archon',
#  'Archy',
#  'Arda',
#  'Ardath',
#  'Ardeen',
#  'Ardelia',
#  'Ardelis',
#  'Ardella',
#  'Ardelle',
#  'Arden',
#  'Ardene',
#  'Ardenia',
#  'Ardine',
#  'Ardis',
#  'Ardith',
#  'Ardra',
#  'Ardyce',
#  'Ardys',
#  'Ardyth',
#  'Arel',
#  'Aretha',
#  'Ari',
#  'Ariadne',
#  'Ariana',
#  'Arianne',
#  'Aridatha',
#  'Arie',
#  'Ariel',
#  'Ariel',
#  'Ariela',
#  'Ariella',
#  'Arielle',
#  'Aristotle',
#  'Arlana',
#  'Arlee',
#  'Arleen',
#  'Arlen',
#  'Arlena',
#  'Arlene',
#  'Arleta',
#  'Arlette',
#  'Arleyne',
#  'Arlie',
#  'Arliene',
#  'Arlina',
#  'Arlinda',
#  'Arline',
#  'Arlo',
#  'Arly',
#  'Arlyn',
#  'Arlyne',
#  'Armand',
#  'Armando',
#  'Armond',
#  'Armstrong',
#  'Arne',
#  'Arnie',
#  'Arnold',
#  'Arnoldo',
#  'Aron',
#  'Arron',
#  'Art',
#  'Arther',
#  'Arthur',
#  'Artie',
#  'Artur',
#  'Arturo',
#  'Arvie',
#  'Arvin',
#  'Arvind',
#  'Arvy',
#  'Aryn',
#  'Ash',
#  'Ashby',
#  'Ashely',
#  'Ashish',
#  'Ashlee',
#  'Ashleigh',
#  'Ashlen',
#  'Ashley',
#  'Ashley',
#  'Ashli',
#  'Ashlie',
#  'Ashly',
#  'Ashton',
#  'Asia',
#  'Astra',
#  'Astrid',
#  'Astrix',
#  'Atalanta',
#  'Athena',
#  'Athene',
#  'Atlanta',
#  'Atlante',
#  'Aub',
#  'Aube',
#  'Aubert',
#  'Auberta',
#  'Aubine',
#  'Aubree',
#  'Aubrette',
#  'Aubrey',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Audi',
#  'Audie',
#  'Audra',
#  'Audre',
#  'Audrey',
#  'Audrie',
#  'Audry',
#  'Audrye',
#  'Audy',
#  'Augie',
#  'August',
#  'Augusta',
#  'Auguste',
#  'Augustin',
#  'Augustina',
#  'Augustine',
#  'Augustine',
#  'Augusto',
#  'Augustus',
#  'Aura',
#  'Aurea',
#  'Aurel',
#  'Aurelea',
#  'Aurelia',
#  'Aurelie',
#  'Auria',
#  'Aurie',
#  'Aurilia',
#  'Aurlie',
#  'Auroora',
#  'Aurora',
#  'Aurore',
#  'Austen',
#  'Austin',
#  'Austin',
#  'Austina',
#  'Austine',
#  'Ava',
#  'Ave',
#  'Aveline',
#  'Averell',
#  'Averil',
#  'Averil',
#  'Averill',
#  'Avery',
#  'Averyl',
#  'Avi',
#  'Avie',
#  'Avis',
#  'Aviva',
#  'Avivah',
#  'Avraham',
#  'Avram',
#  'Avril',
#  'Avrit',
#  'Avrom',
#  'Axel',
#  'Aylmer',
#  'Ayn',
#  'Aziz',
#  'Bab',
#  'Babara',
#  'Babette',
#  'Babita',
#  'Babs',
#  'Bailey',
#  'Bailie',
#  'Baillie',
#  'Baily',
#  'Baird',
#  'Baldwin',
#  'Bambi',
#  'Bambie',
#  'Bamby',
#  'Bancroft',
#  'Barb',
#  'Barbabas',
#  'Barbabra',
#  'Barbara',
#  'Barbara-Anne',
#  'Barbaraanne',
#  'Barbe',
#  'Barbee',
#  'Barbette',
#  'Barbey',
#  'Barbi',
#  'Barbie',
#  'Barbra',
#  'Barby',
#  'Barclay',
#  'Bard',
#  'Barde',
#  'Bari',
#  'Barn',
#  'Barnabas',
#  'Barnabe',
#  'Barnaby',
#  'Barnard',
#  'Barnebas',
#  'Barnett',
#  'Barney',
#  'Barnie',
#  'Barny',
#  'Baron',
#  'Barr',
#  'Barret',
#  'Barrett',
#  'Barri',
#  'Barrie',
#  'Barrie',
#  'Barris',
#  'Barron',
#  'Barry',
#  'Barry',
#  'Bart',
#  'Bartel',
#  'Barth',
#  'Barthel',
#  'Bartholemy',
#  'Bartholomeo',
#  'Bartholomeus',
#  'Bartholomew',
#  'Bartie',
#  'Bartlet',
#  'Bartlett',
#  'Bartolemo',
#  'Bartolomei',
#  'Bartolomeo',
#  'Barton',
#  'Barty',
#  'Bary',
#  'Basia',
#  'Basil',
#  'Batholomew',
#  'Bathsheba',
#  'Batsheva',
#  'Baxter',
#  'Bay',
#  'Bayard',
#  'Bea',
#  'Beale',
#  'Bealle',
#  'Bear',
#  'Bearnard',
#  'Beatrice',
#  'Beatrisa',
#  'Beatrix',
#  'Beatriz',
#  'Beau',
#  'Beau',
#  'Beaufort',
#  'Beauregard',
#  'Bebe',
#  'Becca',
#  'Beck',
#  'Becka',
#  'Becki',
#  'Beckie',
#  'Becky',
#  'Bee',
#  'Beilul',
#  'Beitris',
#  'Bekki',
#  'Bel',
#  'Bela',
#  'Belia',
#  'Belicia',
#  'Belinda',
#  'Belita',
#  'Bell',
#  'Bella',
#  'Bellamy',
#  'Bellanca',
#  'Belle',
#  'Bellina',
#  'Belva',
#  'Belvia',
#  'Ben',
#  'Bendite',
#  'Benedetta',
#  'Benedict',
#  'Benedicta',
#  'Benedikta',
#  'Benetta',
#  'Bengt',
#  'Benita',
#  'Benito',
#  'Benjamen',
#  'Benjamin',
#  'Benji',
#  'Benjie',
#  'Benjy',
#  'Benn',
#  'Bennet',
#  'Bennett',
#  'Benni',
#  'Bennie',
#  'Bennie',
#  'Benny',
#  'Benny',
#  'Benoite',
#  'Benson',
#  'Bentley',
#  'Benton',
#  'Beowulf',
#  'Berchtold',
#  'Berenice',
#  'Beret',
#  'Berget',
#  'Berk',
#  'Berke',
#  'Berkeley',
#  'Berkie',
#  'Berkley',
#  'Berna',
#  'Bernadene',
#  'Bernadette',
#  'Bernadina',
#  'Bernadine',
#  'Bernard',
#  'Bernardina',
#  'Bernardine',
#  'Bernardo',
#  'Bernd',
#  'Bernelle',
#  'Bernete',
#  'Bernetta',
#  'Bernette',
#  'Bernhard',
#  'Berni',
#  'Bernice',
#  'Bernie',
#  'Bernie',
#  'Bernita',
#  'Berny',
#  'Berri',
#  'Berrie',
#  'Berry',
#  'Bert',
#  'Bert',
#  'Berta',
#  'Berte',
#  'Bertha',
#  'Berthe',
#  'Berti',
#  'Bertie',
#  'Bertie',
#  'Bertina',
#  'Bertine',
#  'Bertram',
#  'Bertrand',
#  'Berty',
#  'Beryl',
#  'Beryle',
#  'Bess',
#  'Bessie',
#  'Bessy',
#  'Beth',
#  'Bethanne',
#  'Bethany',
#  'Bethena',
#  'Bethina',
#  'Betsey',
#  'Betsy',
#  'Betta',
#  'Bette',
#  'Bette-Ann',
#  'Betteann',
#  'Betteanne',
#  'Betti',
#  'Bettie',
#  'Bettina',
#  'Bettine',
#  'Betty',
#  'Bettye',
#  'Beulah',
#  'Bev',
#  'Beverie',
#  'Beverlee',
#  'Beverlie',
#  'Beverly',
#  'Bevvy',
#  'Bharat',
#  'Bianca',
#  'Bianka',
#  'Biddy',
#  'Bidget',
#  'Biff',
#  'Bill',
#  'Bill',
#  'Billi',
#  'Billie',
#  'Billie',
#  'Billy',
#  'Billy',
#  'Bing',
#  'Binky',
#  'Binni',
#  'Binnie',
#  'Binny',
#  'Bird',
#  'Birdie',
#  'Birgit',
#  'Birgitta',
#  'Bishop',
#  'Bjorn',
#  'Bjorne',
#  'Blaine',
#  'Blair',
#  'Blair',
#  'Blaire',
#  'Blake',
#  'Blake',
#  'Blakelee',
#  'Blakeley',
#  'Blanca',
#  'Blanch',
#  'Blancha',
#  'Blanche',
#  'Blare',
#  'Blayne',
#  'Blinni',
#  'Blinnie',
#  'Blinny',
#  'Bliss',
#  'Blisse',
#  'Blithe',
#  'Blondell',
#  'Blondelle',
#  'Blondie',
#  'Blondy',
#  'Blythe',
#  'Bo',
#  'Bo',
#  'Bob',
#  'Bobbette',
#  'Bobbi',
#  'Bobbie',
#  'Bobbie',
#  'Bobby',
#  'Bobby',
#  'Bobette',
#  'Bobina',
#  'Bobine',
#  'Bobinette',
#  'Bogart',
#  'Bogdan',
#  'Boniface',
#  'Bonita',
#  'Bonnee',
#  'Bonni',
#  'Bonnie',
#  'Bonny',
#  'Boris',
#  'Boyce',
#  'Boyd',
#  'Brad',
#  'Braden',
#  'Bradford',
#  'Bradley',
#  'Bradly',
#  'Brady',
#  'Brana',
#  'Brandais',
#  'Brande',
#  'Brandea',
#  'Brandi',
#  'Brandice',
#  'Brandie',
#  'Brandise',
#  'Brandon',
#  'Brandy',
#  'Brandy',
#  'Brant',
#  'Brea',
#  'Breanne',
#  'Brear',
#  'Bree',
#  'Breena',
#  'Bren',
#  'Brena',
#  'Brenda',
#  'Brendan',
#  'Brenn',
#  'Brenna',
#  'Brent',
#  'Bret',
#  'Brett',
#  'Brett',
#  'Brewer',
#  'Brewster',
#  'Bria',
#  'Brian',
#  'Briana',
#  'Brianna',
#  'Brianne',
#  'Brice',
#  'Bride',
#  'Bridget',
#  'Bridgett',
#  'Bridgette',
#  'Bridie',
#  'Brier',
#  'Brietta',
#  ...]

# %%
# Performing the function defined earlier (within part 1) on the list of names created above to convert the data into the format required for it to be passed into the NLTK NBCM 
i_names_input = [(gender_features(n))
               for (n)in new_list]

i_names_input
# Out:
# [{'last three letters': 'mir'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'ael'},
#  {'last three letters': 'ail'},
#  {'last three letters': 'bbe'},
#  {'last three letters': 'bey'},
#  {'last three letters': 'bey'},
#  {'last three letters': 'bbi'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'bot'},
#  {'last three letters': 'ott'},
#  {'last three letters': 'bby'},
#  {'last three letters': 'bby'},
#  {'last three letters': 'del'},
#  {'last three letters': 'dul'},
#  {'last three letters': 'rim'},
#  {'last three letters': 'lah'},
#  {'last three letters': 'Abe'},
#  {'last three letters': 'bel'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'ael'},
#  {'last three letters': 'ail'},
#  {'last three letters': 'ale'},
#  {'last three letters': 'ner'},
#  {'last three letters': 'bra'},
#  {'last three letters': 'ham'},
#  {'last three letters': 'ram'},
#  {'last three letters': 'cia'},
#  {'last three letters': 'Ace'},
#  {'last three letters': 'Ada'},
#  {'last three letters': 'dah'},
#  {'last three letters': 'air'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'dam'},
#  {'last three letters': 'ams'},
#  {'last three letters': 'ara'},
#  {'last three letters': 'die'},
#  {'last three letters': 'die'},
#  {'last three letters': 'dis'},
#  {'last three letters': 'del'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'ide'},
#  {'last three letters': 'ele'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ind'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'dey'},
#  {'last three letters': 'ger'},
#  {'last three letters': 'Adi'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'tya'},
#  {'last three letters': 'lai'},
#  {'last three letters': 'nan'},
#  {'last three letters': 'olf'},
#  {'last three letters': 'lfo'},
#  {'last three letters': 'lph'},
#  {'last three letters': 'phe'},
#  {'last three letters': 'pho'},
#  {'last three letters': 'hus'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'ore'},
#  {'last three letters': 'ree'},
#  {'last three letters': 'rne'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'ens'},
#  {'last three letters': 'ian'},
#  {'last three letters': 'ian'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'ane'},
#  {'last three letters': 'nna'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'ick'},
#  {'last three letters': 'ien'},
#  {'last three letters': 'ien'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'iel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'Ag'},
#  {'last three letters': 'ace'},
#  {'last three letters': 'non'},
#  {'last three letters': 'ata'},
#  {'last three letters': 'tha'},
#  {'last three letters': 'the'},
#  {'last three letters': 'ggi'},
#  {'last three letters': 'gie'},
#  {'last three letters': 'ggy'},
#  {'last three letters': 'gna'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'nes'},
#  {'last three letters': 'ese'},
#  {'last three letters': 'sse'},
#  {'last three letters': 'eta'},
#  {'last three letters': 'ola'},
#  {'last three letters': 'tha'},
#  {'last three letters': 'ldo'},
#  {'last three letters': 'ste'},
#  {'last three letters': 'tin'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'mad'},
#  {'last three letters': 'med'},
#  {'last three letters': 'met'},
#  {'last three letters': 'ida'},
#  {'last three letters': 'dan'},
#  {'last three letters': 'eis'},
#  {'last three letters': 'ila'},
#  {'last three letters': 'ile'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'een'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'ili'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'lyn'},
#  {'last three letters': 'ime'},
#  {'last three letters': 'mee'},
#  {'last three letters': 'mil'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'jai'},
#  {'last three letters': 'jay'},
#  {'last three letters': 'jay'},
#  {'last three letters': 'Al'},
#  {'last three letters': 'laa'},
#  {'last three letters': 'ain'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'eda'},
#  {'last three letters': 'lan'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'nah'},
#  {'last three letters': 'ane'},
#  {'last three letters': 'nna'},
#  {'last three letters': 'air'},
#  {'last three letters': 'air'},
#  {'last three letters': 'yne'},
#  {'last three letters': 'ros'},
#  {'last three letters': 'ert'},
#  {'last three letters': 'rta'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'rto'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'cht'},
#  {'last three letters': 'den'},
#  {'last three letters': 'dis'},
#  {'last three letters': 'ldo'},
#  {'last three letters': 'ric'},
#  {'last three letters': 'ich'},
#  {'last three letters': 'dus'},
#  {'last three letters': 'win'},
#  {'last three letters': 'lec'},
#  {'last three letters': 'cia'},
#  {'last three letters': 'eck'},
#  {'last three letters': 'eda'},
#  {'last three letters': 'ece'},
#  {'last three letters': 'cia'},
#  {'last three letters': 'een'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'dro'},
#  {'last three letters': 'eks'},
#  {'last three letters': 'drs'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'dro'},
#  {'last three letters': 'eta'},
#  {'last three letters': 'hea'},
#  {'last three letters': 'lex'},
#  {'last three letters': 'lex'},
#  {'last three letters': 'exa'},
#  {'last three letters': 'der'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'xei'},
#  {'last three letters': 'exi'},
#  {'last three letters': 'xia'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'xis'},
#  {'last three letters': 'xis'},
#  {'last three letters': 'Alf'},
#  {'last three letters': 'fie'},
#  {'last three letters': 'fie'},
#  {'last three letters': 'nse'},
#  {'last three letters': 'nso'},
#  {'last three letters': 'nzo'},
#  {'last three letters': 'ord'},
#  {'last three letters': 'red'},
#  {'last three letters': 'eda'},
#  {'last three letters': 'edo'},
#  {'last three letters': 'non'},
#  {'last three letters': 'Ali'},
#  {'last three letters': 'Ali'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lic'},
#  {'last three letters': 'ica'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'cea'},
#  {'last three letters': 'cia'},
#  {'last three letters': 'ida'},
#  {'last three letters': 'dia'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'lis'},
#  {'last three letters': 'isa'},
#  {'last three letters': 'sha'},
#  {'last three letters': 'son'},
#  {'last three letters': 'ssa'},
#  {'last three letters': 'ter'},
#  {'last three letters': 'sun'},
#  {'last three letters': 'lix'},
#  {'last three letters': 'lix'},
#  {'last three letters': 'iza'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lah'},
#  {'last three letters': 'lan'},
#  {'last three letters': 'een'},
#  {'last three letters': 'gra'},
#  {'last three letters': 'len'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'lli'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'lin'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'lis'},
#  {'last three letters': 'son'},
#  {'last three letters': 'ssa'},
#  {'last three letters': 'sun'},
#  {'last three letters': 'lly'},
#  {'last three letters': 'yce'},
#  {'last three letters': 'lyn'},
#  {'last three letters': 'lyn'},
#  {'last three letters': 'lys'},
#  {'last three letters': 'son'},
#  {'last three letters': 'lma'},
#  {'last three letters': 'eda'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'eta'},
#  {'last three letters': 'ira'},
#  {'last three letters': 'ire'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'nso'},
#  {'last three letters': 'nzo'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'ius'},
#  {'last three letters': 'lpa'},
#  {'last three letters': 'nse'},
#  {'last three letters': 'nso'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'lta'},
#  {'last three letters': 'hea'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'era'},
#  {'last three letters': 'vin'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'nia'},
#  {'last three letters': 'ira'},
#  {'last three letters': 'win'},
#  {'last three letters': 'yce'},
#  {'last three letters': 'yda'},
#  {'last three letters': 'lys'},
#  {'last three letters': 'ysa'},
#  {'last three letters': 'yse'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'son'},
#  {'last three letters': 'yss'},
#  {'last three letters': 'ssa'},
#  {'last three letters': 'bel'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'eus'},
#  {'last three letters': 'lea'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'eta'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'nda'},
#  {'last three letters': 'ndi'},
#  {'last three letters': 'die'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'ara'},
#  {'last three letters': 'rgo'},
#  {'last three letters': 'ata'},
#  {'last three letters': 'ber'},
#  {'last three letters': 'rly'},
#  {'last three letters': 'ros'},
#  {'last three letters': 'ose'},
#  {'last three letters': 'osi'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'sio'},
#  {'last three letters': 'ius'},
#  {'last three letters': 'bur'},
#  {'last three letters': 'Ame'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'ery'},
#  {'last three letters': 'Ami'},
#  {'last three letters': 'mie'},
#  {'last three letters': 'ity'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'ory'},
#  {'last three letters': 'mos'},
#  {'last three letters': 'Amy'},
#  {'last three letters': 'Ana'},
#  {'last three letters': 'bel'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ais'},
#  {'last three letters': 'ese'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'ese'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'sie'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'tol'},
#  {'last three letters': 'ola'},
#  {'last three letters': 'ole'},
#  {'last three letters': 'llo'},
#  {'last three letters': 'oly'},
#  {'last three letters': 'dee'},
#  {'last three letters': 'ers'},
#  {'last three letters': 'ndi'},
#  {'last three letters': 'die'},
#  {'last three letters': 'die'},
#  {'last three letters': 'nis'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'dre'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'eas'},
#  {'last three letters': 'ree'},
#  {'last three letters': 'rei'},
#  {'last three letters': 'rej'},
#  {'last three letters': 'res'},
#  {'last three letters': 'rew'},
#  {'last three letters': 'rey'},
#  {'last three letters': 'dri'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'che'},
#  {'last three letters': 'eda'},
#  {'last three letters': 'ros'},
#  {'last three letters': 'rus'},
#  {'last three letters': 'zej'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'net'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'nge'},
#  {'last three letters': 'gel'},
#  {'last three letters': 'gel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'ele'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'ica'},
#  {'last three letters': 'ico'},
#  {'last three letters': 'ika'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'que'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'elo'},
#  {'last three letters': 'gie'},
#  {'last three letters': 'gie'},
#  {'last three letters': 'gil'},
#  {'last three letters': 'gus'},
#  {'last three letters': 'ngy'},
#  {'last three letters': 'nia'},
#  {'last three letters': 'ica'},
#  {'last three letters': 'ssa'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'tra'},
#  {'last three letters': 'nja'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'Ann'},
#  {'last three letters': 'ari'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'nna'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'ane'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'bal'},
#  {'last three letters': 'bel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'ane'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ese'},
#  {'last three letters': 'isa'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'yse'},
#  {'last three letters': 'ari'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'Mar'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'ese'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'nni'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'ssa'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'sel'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'elm'},
#  {'last three letters': 'lma'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'son'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'the'},
#  {'last three letters': 'hea'},
#  {'last three letters': 'hia'},
#  {'last three letters': 'ony'},
#  {'last three letters': 'tin'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'one'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'oni'},
#  {'last three letters': 'nia'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'nin'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ino'},
#  {'last three letters': 'nio'},
#  {'last three letters': 'ius'},
#  {'last three letters': 'ony'},
#  {'last three letters': 'rag'},
#  {'last three letters': 'nya'},
#  {'last three letters': 'ite'},
#  {'last three letters': 'llo'},
#  {'last three letters': 'los'},
#  {'last three letters': 'nia'},
#  {'last three letters': 'ril'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'Ara'},
#  {'last three letters': 'bel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'ele'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ram'},
#  {'last three letters': 'ald'},
#  {'last three letters': 'old'},
#  {'last three letters': 'hie'},
#  {'last three letters': 'hon'},
#  {'last three letters': 'chy'},
#  {'last three letters': 'rda'},
#  {'last three letters': 'ath'},
#  {'last three letters': 'een'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lis'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'den'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'nia'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'dis'},
#  {'last three letters': 'ith'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'yce'},
#  {'last three letters': 'dys'},
#  {'last three letters': 'yth'},
#  {'last three letters': 'rel'},
#  {'last three letters': 'tha'},
#  {'last three letters': 'Ari'},
#  {'last three letters': 'dne'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'tha'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'iel'},
#  {'last three letters': 'iel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'tle'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'een'},
#  {'last three letters': 'len'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'eta'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'yne'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'nda'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'rlo'},
#  {'last three letters': 'rly'},
#  {'last three letters': 'lyn'},
#  {'last three letters': 'yne'},
#  {'last three letters': 'and'},
#  {'last three letters': 'ndo'},
#  {'last three letters': 'ond'},
#  {'last three letters': 'ong'},
#  {'last three letters': 'rne'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'old'},
#  {'last three letters': 'ldo'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'Art'},
#  {'last three letters': 'her'},
#  {'last three letters': 'hur'},
#  {'last three letters': 'tie'},
#  {'last three letters': 'tur'},
#  {'last three letters': 'uro'},
#  {'last three letters': 'vie'},
#  {'last three letters': 'vin'},
#  {'last three letters': 'ind'},
#  {'last three letters': 'rvy'},
#  {'last three letters': 'ryn'},
#  {'last three letters': 'Ash'},
#  {'last three letters': 'hby'},
#  {'last three letters': 'ely'},
#  {'last three letters': 'ish'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'igh'},
#  {'last three letters': 'len'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'hli'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'hly'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'tra'},
#  {'last three letters': 'rid'},
#  {'last three letters': 'rix'},
#  {'last three letters': 'nta'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'nta'},
#  {'last three letters': 'nte'},
#  {'last three letters': 'Aub'},
#  {'last three letters': 'ube'},
#  {'last three letters': 'ert'},
#  {'last three letters': 'rta'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ree'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'rey'},
#  {'last three letters': 'rey'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'bry'},
#  {'last three letters': 'udi'},
#  {'last three letters': 'die'},
#  {'last three letters': 'dra'},
#  {'last three letters': 'dre'},
#  {'last three letters': 'rey'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'dry'},
#  {'last three letters': 'rye'},
#  {'last three letters': 'udy'},
#  {'last three letters': 'gie'},
#  {'last three letters': 'ust'},
#  {'last three letters': 'sta'},
#  {'last three letters': 'ste'},
#  {'last three letters': 'tin'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'sto'},
#  {'last three letters': 'tus'},
#  {'last three letters': 'ura'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'rel'},
#  {'last three letters': 'lea'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'ora'},
#  {'last three letters': 'ore'},
#  {'last three letters': 'ten'},
#  {'last three letters': 'tin'},
#  {'last three letters': 'tin'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'Ava'},
#  {'last three letters': 'Ave'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'ril'},
#  {'last three letters': 'ril'},
#  {'last three letters': 'ill'},
#  {'last three letters': 'ery'},
#  {'last three letters': 'ryl'},
#  {'last three letters': 'Avi'},
#  {'last three letters': 'vie'},
#  {'last three letters': 'vis'},
#  {'last three letters': 'iva'},
#  {'last three letters': 'vah'},
#  {'last three letters': 'ham'},
#  {'last three letters': 'ram'},
#  {'last three letters': 'ril'},
#  {'last three letters': 'rit'},
#  {'last three letters': 'rom'},
#  {'last three letters': 'xel'},
#  {'last three letters': 'mer'},
#  {'last three letters': 'Ayn'},
#  {'last three letters': 'ziz'},
#  {'last three letters': 'Bab'},
#  {'last three letters': 'ara'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'abs'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'ily'},
#  {'last three letters': 'ird'},
#  {'last three letters': 'win'},
#  {'last three letters': 'mbi'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'mby'},
#  {'last three letters': 'oft'},
#  {'last three letters': 'arb'},
#  {'last three letters': 'bas'},
#  {'last three letters': 'bra'},
#  {'last three letters': 'ara'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'rbe'},
#  {'last three letters': 'bee'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'bey'},
#  {'last three letters': 'rbi'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'bra'},
#  {'last three letters': 'rby'},
#  {'last three letters': 'lay'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'rde'},
#  {'last three letters': 'ari'},
#  {'last three letters': 'arn'},
#  {'last three letters': 'bas'},
#  {'last three letters': 'abe'},
#  {'last three letters': 'aby'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'bas'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'ney'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'rny'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'arr'},
#  {'last three letters': 'ret'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'rri'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'ris'},
#  {'last three letters': 'ron'},
#  {'last three letters': 'rry'},
#  {'last three letters': 'rry'},
#  {'last three letters': 'art'},
#  {'last three letters': 'tel'},
#  {'last three letters': 'rth'},
#  {'last three letters': 'hel'},
#  {'last three letters': 'emy'},
#  {'last three letters': 'meo'},
#  {'last three letters': 'eus'},
#  {'last three letters': 'mew'},
#  {'last three letters': 'tie'},
#  {'last three letters': 'let'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'emo'},
#  {'last three letters': 'mei'},
#  {'last three letters': 'meo'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'rty'},
#  {'last three letters': 'ary'},
#  {'last three letters': 'sia'},
#  {'last three letters': 'sil'},
#  {'last three letters': 'mew'},
#  {'last three letters': 'eba'},
#  {'last three letters': 'eva'},
#  {'last three letters': 'ter'},
#  {'last three letters': 'Bay'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'Bea'},
#  {'last three letters': 'ale'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ear'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'isa'},
#  {'last three letters': 'rix'},
#  {'last three letters': 'riz'},
#  {'last three letters': 'eau'},
#  {'last three letters': 'eau'},
#  {'last three letters': 'ort'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'ebe'},
#  {'last three letters': 'cca'},
#  {'last three letters': 'eck'},
#  {'last three letters': 'cka'},
#  {'last three letters': 'cki'},
#  {'last three letters': 'kie'},
#  {'last three letters': 'cky'},
#  {'last three letters': 'Bee'},
#  {'last three letters': 'lul'},
#  {'last three letters': 'ris'},
#  {'last three letters': 'kki'},
#  {'last three letters': 'Bel'},
#  {'last three letters': 'ela'},
#  {'last three letters': 'lia'},
#  {'last three letters': 'cia'},
#  {'last three letters': 'nda'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'lla'},
#  {'last three letters': 'amy'},
#  {'last three letters': 'nca'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'lva'},
#  {'last three letters': 'via'},
#  {'last three letters': 'Ben'},
#  {'last three letters': 'ite'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'ict'},
#  {'last three letters': 'cta'},
#  {'last three letters': 'kta'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'ngt'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'ito'},
#  {'last three letters': 'men'},
#  {'last three letters': 'min'},
#  {'last three letters': 'nji'},
#  {'last three letters': 'jie'},
#  {'last three letters': 'njy'},
#  {'last three letters': 'enn'},
#  {'last three letters': 'net'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'nni'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'ite'},
#  {'last three letters': 'son'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'ton'},
#  {'last three letters': 'ulf'},
#  {'last three letters': 'old'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'ret'},
#  {'last three letters': 'get'},
#  {'last three letters': 'erk'},
#  {'last three letters': 'rke'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'kie'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'rna'},
#  {'last three letters': 'ene'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'rdo'},
#  {'last three letters': 'rnd'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'ete'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ard'},
#  {'last three letters': 'rni'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'rny'},
#  {'last three letters': 'rri'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'rry'},
#  {'last three letters': 'ert'},
#  {'last three letters': 'ert'},
#  {'last three letters': 'rta'},
#  {'last three letters': 'rte'},
#  {'last three letters': 'tha'},
#  {'last three letters': 'the'},
#  {'last three letters': 'rti'},
#  {'last three letters': 'tie'},
#  {'last three letters': 'tie'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'ram'},
#  {'last three letters': 'and'},
#  {'last three letters': 'rty'},
#  {'last three letters': 'ryl'},
#  {'last three letters': 'yle'},
#  {'last three letters': 'ess'},
#  {'last three letters': 'sie'},
#  {'last three letters': 'ssy'},
#  {'last three letters': 'eth'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'any'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'sey'},
#  {'last three letters': 'tsy'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'Ann'},
#  {'last three letters': 'ann'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'tti'},
#  {'last three letters': 'tie'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'tty'},
#  {'last three letters': 'tye'},
#  {'last three letters': 'lah'},
#  {'last three letters': 'Bev'},
#  {'last three letters': 'rie'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'rly'},
#  {'last three letters': 'vvy'},
#  {'last three letters': 'rat'},
#  {'last three letters': 'nca'},
#  {'last three letters': 'nka'},
#  {'last three letters': 'ddy'},
#  {'last three letters': 'get'},
#  {'last three letters': 'iff'},
#  {'last three letters': 'ill'},
#  {'last three letters': 'ill'},
#  {'last three letters': 'lli'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'lie'},
#  {'last three letters': 'lly'},
#  {'last three letters': 'lly'},
#  {'last three letters': 'ing'},
#  {'last three letters': 'nky'},
#  {'last three letters': 'nni'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'ird'},
#  {'last three letters': 'die'},
#  {'last three letters': 'git'},
#  {'last three letters': 'tta'},
#  {'last three letters': 'hop'},
#  {'last three letters': 'orn'},
#  {'last three letters': 'rne'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'air'},
#  {'last three letters': 'air'},
#  {'last three letters': 'ire'},
#  {'last three letters': 'ake'},
#  {'last three letters': 'ake'},
#  {'last three letters': 'lee'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'nca'},
#  {'last three letters': 'nch'},
#  {'last three letters': 'cha'},
#  {'last three letters': 'che'},
#  {'last three letters': 'are'},
#  {'last three letters': 'yne'},
#  {'last three letters': 'nni'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'iss'},
#  {'last three letters': 'sse'},
#  {'last three letters': 'the'},
#  {'last three letters': 'ell'},
#  {'last three letters': 'lle'},
#  {'last three letters': 'die'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'the'},
#  {'last three letters': 'Bo'},
#  {'last three letters': 'Bo'},
#  {'last three letters': 'Bob'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'bbi'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'bie'},
#  {'last three letters': 'bby'},
#  {'last three letters': 'bby'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'ina'},
#  {'last three letters': 'ine'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'art'},
#  {'last three letters': 'dan'},
#  {'last three letters': 'ace'},
#  {'last three letters': 'ita'},
#  {'last three letters': 'nee'},
#  {'last three letters': 'nni'},
#  {'last three letters': 'nie'},
#  {'last three letters': 'nny'},
#  {'last three letters': 'ris'},
#  {'last three letters': 'yce'},
#  {'last three letters': 'oyd'},
#  {'last three letters': 'rad'},
#  {'last three letters': 'den'},
#  {'last three letters': 'ord'},
#  {'last three letters': 'ley'},
#  {'last three letters': 'dly'},
#  {'last three letters': 'ady'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'ais'},
#  {'last three letters': 'nde'},
#  {'last three letters': 'dea'},
#  {'last three letters': 'ndi'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'die'},
#  {'last three letters': 'ise'},
#  {'last three letters': 'don'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'ndy'},
#  {'last three letters': 'ant'},
#  {'last three letters': 'rea'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'ear'},
#  {'last three letters': 'ree'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'ren'},
#  {'last three letters': 'ena'},
#  {'last three letters': 'nda'},
#  {'last three letters': 'dan'},
#  {'last three letters': 'enn'},
#  {'last three letters': 'nna'},
#  {'last three letters': 'ent'},
#  {'last three letters': 'ret'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'wer'},
#  {'last three letters': 'ter'},
#  {'last three letters': 'ria'},
#  {'last three letters': 'ian'},
#  {'last three letters': 'ana'},
#  {'last three letters': 'nna'},
#  {'last three letters': 'nne'},
#  {'last three letters': 'ice'},
#  {'last three letters': 'ide'},
#  {'last three letters': 'get'},
#  {'last three letters': 'ett'},
#  {'last three letters': 'tte'},
#  {'last three letters': 'die'},
#  {'last three letters': 'ier'},
#  {'last three letters': 'tta'},
#  ...]

# %%
# Creating a new list variable to store results
# Looping through every test name from above list and calling the classifier object (NLTK NBCM) with the classify method to generate a geneder prediction for each of the test names
i_names_pred = []
for names in i_names_input:
    pred = classifier.classify(names)
    i_names_pred.append(pred)

i_names_pred
# Out:
# ['M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  ...]

# %% [markdown]
# # Step 4: Creating New DF with Test First Names and Associated NLTK NBCM Predictions
# #### Notes
# * The NLTK Naive Bayes Classification Model was trained using the US Social Security name-gender data opposed to the NLTK default name-gender data because the  default NLTK name-gender data is being used for testing, thereby if the model was trained using the testing data the model's predictions would likely not be valid due to overfitting

# %%
mega_list_df = pd.DataFrame(data=[new_list, i_names_pred]).T.rename(columns={0: "first_name", 1: "NLTK_gender"})
mega_list_df
# Out:
#      first_name NLTK_gender
# 0         Aamir           M
# 1         Aaron           M
# 2       Abagael           M
# 3       Abagail           M
# 4          Abbe           F
# ...         ...         ...
# 7939      Zorro           M
# 7940    Zsa Zsa           F
# 7941     Zsazsa           F
# 7942     Zulema           F
# 7943     Zuzana           F
#
# [7944 rows x 2 columns]

# %% [markdown]
# # Step 5: Adding to Above DF to Contribute to Final Results DF: 'mega_list_df'
# #### Notes
# * Various columns from the 'rnf_final' DF are appended to 'mega_list_df' for final overall model evaluation purposes

# %%
mega_list_df["RNF_gender"] = rnf_final["gender"]
mega_list_df["Actual"] = rnf_final["Actual"]
mega_list_df["RNF_eval"] = rnf_final["Evaluation"]
mega_list_df
# Out:
#      first_name NLTK_gender RNF_gender Actual RNF_eval
# 0         Aamir           M          M      M        C
# 1         Aaron           M          M      M        C
# 2       Abagael           M          F      F        C
# 3       Abagail           M          F      F        C
# 4          Abbe           F          F      F        C
# ...         ...         ...        ...    ...      ...
# 7939      Zorro           M          U      M        I
# 7940    Zsa Zsa           F          U      F        I
# 7941     Zsazsa           F          F      F        C
# 7942     Zulema           F          F      F        C
# 7943     Zuzana           F          F      F        C
#
# [7944 rows x 5 columns]

# %% [markdown]
# ## Note:
# * Since the current 'RNF_eval' column has denoted a "C" only to correct predictions, it will not suffice to filter this column on "I" when creating our our final hybrid model predictions
# * This is because although we have the luxury of knowing whether each RNF function gender prediction was correct right now, we do not have that luxury when running the main ML model since it is ran using unsupervised data (Ontario Sunshine List genders are not known ... whole point of our model is to generate these predictions as accurately as possible)
# * Therefore, to get the most accurate and honest evaluation of our model, it was decided that we must only take the NLTK-NBCM ('NlTK_gender' column below) predictions for the first names that the RNF model could not predict ("U" and "EV" predictions) because this is how it is done in the main model due to the use of unsupervised data
# * To do this, another column must be added that classfies the RNF predictions in more detail as seen below ('RNF_Better_Eval')
# * Essentially, below for loop allows us to further classify the RNF gender predictions so we know which rows to take the NLTK-NBCM predictions for in creating the final hybrid model's predictions (remember, the real model only passes the first names that could not be predicted ("U" or "EV") using the RNF model, to the NLTK-NBCM

# %%
# Since the current 'RNF_eval' column has denoted a "C" only to correct predictions, it will not suffice to filter this column on "I" in coming to our final hybrid model predictions
# This is because although we have the luxury of knowing whether each RNF function gender prediction was correct right now, we do not have that luxury when running the main ML model, therefore, to get the most accurate and honest accuracy scores, it was decided that we must only take the NLTK-NBCM ('NlTK_gender' column below) predictions for the first names that the RNF model could not predict ("U" and "EV" predictions)
# To do this, another column must be added that classfies the RNF predictions in more detail as seen below ('RNF_Better_Eval')
# Essentially, below for loop allows us to further classify the RNF gender predictions so we know which rows to take the NLTK-NBCM predictions for in creating the final hybrid model's predictions (remember, the real model only passes the first names that could not be predicted ("U" or "EV") using the RNF model, to the NLTK-NBCM
rnf_u_names = []
for row in mega_list_df.itertuples():
    if row[3] == "U":
        rnf_u_names.append("RNF-Unknown")
    elif ((row[3] == "M") or (row[3] == "F")) & (row[5] == "I"):
        rnf_u_names.append("RNF-Incorrect")
    elif ((row[3] == "M") or (row[3] == "F")) & (row[5] == "C"):
        rnf_u_names.append("RNF-Correct")
    else:
        rnf_u_names.append("RNF-EV")
        
mega_list_df["RNF_Better_Eval"] = rnf_u_names

mega_list_df
# Out:
#      first_name NLTK_gender RNF_gender Actual RNF_eval RNF_Better_Eval
# 0         Aamir           M          M      M        C     RNF-Correct
# 1         Aaron           M          M      M        C     RNF-Correct
# 2       Abagael           M          F      F        C     RNF-Correct
# 3       Abagail           M          F      F        C     RNF-Correct
# 4          Abbe           F          F      F        C     RNF-Correct
# ...         ...         ...        ...    ...      ...             ...
# 7939      Zorro           M          U      M        I     RNF-Unknown
# 7940    Zsa Zsa           F          U      F        I     RNF-Unknown
# 7941     Zsazsa           F          F      F        C     RNF-Correct
# 7942     Zulema           F          F      F        C     RNF-Correct
# 7943     Zuzana           F          F      F        C     RNF-Correct
#
# [7944 rows x 6 columns]

# %%
mega_list_df.value_counts("RNF_Better_Eval")
# Out:
# RNF_Better_Eval
# RNF-Correct      6292
# RNF-Unknown      1046
# RNF-Incorrect     604
# RNF-EV              2
# dtype: int64

# %% [markdown]
# # Step 6: Generating Final Hybrid Model Gender Predictions for Test Names Data
# #### Notes
# * Declaring an emtpy list variable to hold results
# * Looping through 'mega_list_df'
# * Applying conditionals so that if the RNF function output a valid gender prediction (correct or incorrect) --> this gender will be appended to the list --> but if the RNF function output "U" or "EV" --> the NLTK gender prediction will be appended to the list
# * This is done because in our ML model, only the names that are given an RNF prediction of "U" or"EV" are then passed through the NLTK Naive Bayes Classifier opposed to including the incorrect RNF predictions because when we used our model to predict the gender of the unique first names contained in the Sunshine List, we do not know which RNF predictions are correct or incorrect since we are not given gender, thereby employing this method here provides a more representative process replication to our actual ML model and thereby increases the credibility of this model evaluation process

# %%
final_hybrid_gender_preds = []

for row in mega_list_df.itertuples():
    if (row.RNF_Better_Eval == "RNF-Correct") or (row.RNF_Better_Eval == "RNF-Incorrect"):
        final_hybrid_gender_preds.append(row[3])
    elif (row.RNF_Better_Eval == "RNF-Unknown") or (row.RNF_Better_Eval == "RNF-EV"):
        final_hybrid_gender_preds.append(row[2])

final_hybrid_gender_preds
# Out:
# ['M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  ...]

# %%
mega_list_df["hybrid_preds"] = final_hybrid_gender_preds
mega_list_df
# Out:
#      first_name NLTK_gender RNF_gender Actual RNF_eval RNF_Better_Eval  \
# 0         Aamir           M          M      M        C     RNF-Correct
# 1         Aaron           M          M      M        C     RNF-Correct
# 2       Abagael           M          F      F        C     RNF-Correct
# 3       Abagail           M          F      F        C     RNF-Correct
# 4          Abbe           F          F      F        C     RNF-Correct
# ...         ...         ...        ...    ...      ...             ...
# 7939      Zorro           M          U      M        I     RNF-Unknown
# 7940    Zsa Zsa           F          U      F        I     RNF-Unknown
# 7941     Zsazsa           F          F      F        C     RNF-Correct
# 7942     Zulema           F          F      F        C     RNF-Correct
# 7943     Zuzana           F          F      F        C     RNF-Correct
#
#      hybrid_preds
# 0               M
# 1               M
# 2               F
# 3               F
# 4               F
# ...           ...
# 7939            M
# 7940            F
# 7941            F
# 7942            F
# 7943            F
#
# [7944 rows x 7 columns]

# %%
final_accuracy = []
for row in mega_list_df.itertuples():
    if (row[4] == "M") & (row[7] == "M"):
        final_accuracy.append("C")
    elif (row[4] == "M") & (row[7] == "F"):
        final_accuracy.append("I")
    elif (row[4] == "F") & (row[7] == "F"):
        final_accuracy.append("C")
    elif (row[4] == "F") & (row[7] == "M"):
        final_accuracy.append("I")

mega_list_df["hybrid_eval"] = final_accuracy
mega_list_df.value_counts("hybrid_eval")
# Out:
# hybrid_eval
# C    7112
# I     832
# dtype: int64

# %%
hybrid_accuracy_score = (7112)/(7112+832)*100

# %%
print(f"Once all of the 'U' or 'EV' (Unknown / even probability RLF predictions ... which both resulted in an 'I' evaluation value which stands for 'Incorrect') gender predictions are extracted from the RLF output and passed to the NLTK Naive Bayes Classification Model the overall hybrid model's accuracy score increases from ~79.2% to {hybrid_accuracy_score:.2f}% accurate.")
# Out:
# Once all of the 'U' or 'EV' (Unknown / even probability RLF predictions ... which both resulted in an 'I' evaluation value which stands for 'Incorrect') gender predictions are extracted from the RLF output and passed to the NLTK Naive Bayes Classification Model the overall hybrid model's accuracy score increases from ~79.2% to 89.53% accurate.

# %% [markdown]
# # Displaying Final Hybrid ML Model DF

# %%
# Dropping the prior (more high-level) 'RNF_eval' column used in part 1 to determine how many of the RNF Function's predictions were correct because we now have the more telling 'RNF_Better_Eval' column
# Displaying the final DF which presents all relevant columns including the final hybrid predictions and their evaluations
mega_list_df_final = mega_list_df.drop(["RNF_eval"], axis=1)
column_names_final = ["first_name", "Actual", "RNF_gender", "NLTK_gender", "RNF_Better_Eval", "hybrid_preds", "hybrid_eval"]
mega_list_df_final = mega_list_df_final.reindex(columns=column_names_final)
mega_list_df_final
# Out:
#      first_name Actual RNF_gender NLTK_gender RNF_Better_Eval hybrid_preds  \
# 0         Aamir      M          M           M     RNF-Correct            M
# 1         Aaron      M          M           M     RNF-Correct            M
# 2       Abagael      F          F           M     RNF-Correct            F
# 3       Abagail      F          F           M     RNF-Correct            F
# 4          Abbe      F          F           F     RNF-Correct            F
# ...         ...    ...        ...         ...             ...          ...
# 7939      Zorro      M          U           M     RNF-Unknown            M
# 7940    Zsa Zsa      F          U           F     RNF-Unknown            F
# 7941     Zsazsa      F          F           F     RNF-Correct            F
# 7942     Zulema      F          F           F     RNF-Correct            F
# 7943     Zuzana      F          F           F     RNF-Correct            F
#
#      hybrid_eval
# 0              C
# 1              C
# 2              C
# 3              C
# 4              C
# ...          ...
# 7939           C
# 7940           C
# 7941           C
# 7942           C
# 7943           C
#
# [7944 rows x 7 columns]

# %% [markdown]
# # Just to show NLTK Naive Bayes Classification Model Accuracy on its Own

# %%
final_accuracy_1 = []
for row in mega_list_df.itertuples():
    if (row[4] == "M") & (row[2] == "M"):
        final_accuracy_1.append("C")
    elif (row[4] == "M") & (row[2] == "F"):
        final_accuracy_1.append("I")
    elif (row[4] == "F") & (row[2] == "F"):
        final_accuracy_1.append("C")
    elif (row[4] == "F") & (row[2] == "M"):
        final_accuracy_1.append("I")
        
        
NLTK_mega_list_df = mega_list_df_final
NLTK_mega_list_df["NLTK_eval"] = final_accuracy_1
NLTK_mega_list_df
# Out:
#      first_name NLTK_gender RNF_gender Actual RNF_Better_Eval hybrid_preds  \
# 0         Aamir           M          M      M     RNF-Correct            M
# 1         Aaron           M          M      M     RNF-Correct            M
# 2       Abagael           M          F      F     RNF-Correct            F
# 3       Abagail           M          F      F     RNF-Correct            F
# 4          Abbe           F          F      F     RNF-Correct            F
# ...         ...         ...        ...    ...             ...          ...
# 7939      Zorro           M          U      M     RNF-Unknown            M
# 7940    Zsa Zsa           F          U      F     RNF-Unknown            F
# 7941     Zsazsa           F          F      F     RNF-Correct            F
# 7942     Zulema           F          F      F     RNF-Correct            F
# 7943     Zuzana           F          F      F     RNF-Correct            F
#
#      hybrid_eval NLTK_eval
# 0              C         C
# 1              C         C
# 2              C         I
# 3              C         I
# 4              C         C
# ...          ...       ...
# 7939           C         C
# 7940           C         C
# 7941           C         C
# 7942           C         C
# 7943           C         C
#
# [7944 rows x 8 columns]

# %%
NLTK_mega_list_df.value_counts("NLTK_eval")
# Out:
# NLTK_eval
# C    6373
# I    1571
# dtype: int64

# %%
NLTK_accuracy_score = (6373) / (6373+1571)*100
NLTK_accuracy_score
# Out:
# 80.2240684793555

# %%
print(f"The accuracy score of the NLTK Naive Bayes Classification Model alone, as tested by training it with the same training data fed into the RNF function (US Social Security Data) is {NLTK_accuracy_score:.2f}% accurate. Only 1% better than the RNF function alone when trained with the same data.")
# Out:
# The accuracy score of the NLTK Naive Bayes Classification Model alone, as tested by training it with the same training data fed into the RNF function (US Social Security Data) is 80.22% accurate. Only 1% better than the RNF function alone when trained with the same data.
